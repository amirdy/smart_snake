# %%
# Import Packages
import time
import torch
import numpy as np 
import matplotlib.pyplot as plt
import torch.cuda as cuda
import pickle
from tensorflow.python.client import device_lib
from google.colab import drive

# Import My Modules 
from snake_class import Agent 
from food_class import meal, food_init
from network import net

drive.mount('/content/drive')

memory = {} # The Replay Memory
memory_pointer = 0 

lr = 0.001

reward_food = 100
reward_loose = -100
reward_move = -0.1

features = 8 # Number of features

gamma = 0.99
batch_size = 128
M = 30000 # Number of Episodes

ep_min = 0.0001
delta_ep = 0.00001
e = 1 # The initial epsilon

dimension = 10 + 2

max_memory_size = 50000
target_update = 10
total_steps = 0

action_to_direction = {0:"Left" , 1:"Right", 2:"Up", 3:"Down"}


print(device_lib.list_local_devices()) # Show the GPU & CPU Specifications
# Out:
# Mounted at /content/drive
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 2785364831050025199
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 8374941654167369024
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 7214572898068590558
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14618221632
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 16840787413689311114
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %%
# Network

Q_policy=net(features,4) # Q_theta
Q_target=net(features,4) # Q_theta-

Q_target.load_state_dict(Q_policy.state_dict())
Q_target.eval()

Q_target.double()
Q_policy.double()


criterion=torch.nn.MSELoss()
optimizer=torch.optim.RMSprop(Q_policy.parameters(), lr=lr)

if cuda.is_available():
          Q_policy = Q_policy.cuda()
          Q_target = Q_target.cuda()

# %%
# Training

from functions import return_state, return_batch_X, cal_Y, epsilon_greedy

start_time = time.time() 
end = 0 # Not end
total_steps = 0
scores = []
counter = 200 # Counter of saving networks and showing the result

for episode in range(1, M+1):
    if episode % counter == 0  :
        # print(total_steps)
        print("Episode {0:5d} started -->".format(episode),end="  ")
        if total_steps < 2000:
          print(" No Training")

    # Initializing the snake and food positions
    snake= Agent(dimension)
    food,_ = food_init(dimension,snake.path)    
    current_state = return_state(snake.path , food)  #  np array ([1, features])  
    
    loose = False # Loose : Snake runs into the wall or runs into itslef
    isFinished = False # The game ends when the snake eats all the foods

    Losses = 0
    step = 0
    score = 0 

    while loose != True: # Not loose

        tensor_current_state = torch.from_numpy(current_state)
        if cuda.is_available():
          tensor_current_state = tensor_current_state.cuda()
        
        Q_policy.eval()
        with torch.no_grad():
          out = Q_policy(tensor_current_state)

        best_action = int(torch.argmax( out ))

        action = epsilon_greedy(best_action) # action is 0, 1, 2 or 3 
    
        snake.move(action_to_direction[action],dimension)
        step += 1
        total_steps += 1

        if snake.head[0] == food.x and snake.head[1] == food.y:  # Eating food
            score += 1
            reward = reward_food
            food, isFinished = food_init(dimension,snake.path) # Initializing the food position
            loose = isFinished
            end = int(isFinished)
            new_state = return_state(snake.path , food) #  np array ([1, features])  

   
        elif snake.head in snake.path[1:-1]: # Loose : runs into itself
            loose = True
            reward = reward_loose
            end = 1 # True
            snake.path.pop(0) # Removing the tail
            new_state = return_state(snake.path , food)  #  np array ([1, features])  
            scores.append(score)
           
            
        elif (snake.head[0] in [0,dimension-1]) or (snake.head[1] in [0,dimension-1]): # Loose : runs into the wall
            loose = True
            reward = reward_loose
            end = 1 # True
            snake.path.pop(0) # Removing the tail
            new_state = return_state(snake.path , food)  #  np array ([1, features])  
            scores.append(score)
        
        else : # Just moved
            reward = reward_move
            end = 0 # False
            snake.path.pop(0) # Removing the tail
            new_state = return_state(snake.path , food)  #  np array ([1, features])  

        #### save in memory ###
        if memory_pointer < (max_memory_size-1):
                  memory[memory_pointer] = [current_state, action, reward, new_state,end]
        else :
                  memory_pointer = 0
                  memory[memory_pointer] = [current_state, action, reward, new_state,end]
        memory_pointer += 1

        if total_steps > 2000: # Training will start after the first 2000 steps
          X, indexes = return_batch_X(memory) #  X : torch.Size([batch_size, features])   
          if cuda.is_available():
            X = X.cuda()

          Q_policy.train()
          outputs = Q_policy(X) # output: torch.Size([batchsize, 4]) | 4 is number of output neurons
          actions = [[memory[i][1]] for i in indexes] # contains actions of mini-batch stored in the memory
          
          tensor_actions = torch.tensor(actions)
          if cuda.is_available():
                    tensor_actions = tensor_actions.cuda()

          outputs = torch.gather(outputs, 1, tensor_actions ) # outputs :  torch.Size([batch_size , 1])      

          Y = cal_Y(indexes,memory) # Y :  torch.Size([batch_size , 1])

          if cuda.is_available():
            Y = Y.cuda()

          loss = criterion(outputs,Y.detach())

          optimizer.zero_grad()
          loss.backward()
          optimizer.step()

          Losses += loss.data
          current_state = new_state.copy()
          if (loose == True) :
              if episode % counter == 0:
                print("Total Transitions(Until end of this episode) : {0:7d}".format(total_steps),end=" | ")
                print("Transitions(this episode) : {0:3d}".format(step),end=" | ")
                print("Score : {0:2d}".format(score),end=" | ")
                print("Loss : {0:.3f}".format(Losses/step),end=" | ")
                print("Mean scores of last {0} episodes : {1:.3f}".format(1000,np.mean(scores[-1000:])))

              # begin the next episode
        

    if total_steps % target_update == 0 :
            Q_target.load_state_dict(Q_policy.state_dict())
    

    if episode % counter == 0:
       PATH="/content/drive/My Drive/policy_network.pth"
       torch.save({
              'Q_policy_state_dict': Q_policy.state_dict()  
              }, PATH)

print("**** Finished in ~ {} Minutes".format(int((time.time() - start_time)/60)))
# Out:
# Episode   200 started -->   No Training
# Episode   400 started -->   No Training
# Episode   600 started -->   No Training
# Episode   800 started -->  Total Transitions(Until end of this episode) :    2498 | Transitions(this episode) :   2 | Score :  0 | Loss : 1182.174 | Mean scores of last 1000 episodes : 0.018
# Episode  1000 started -->  Total Transitions(Until end of this episode) :    3058 | Transitions(this episode) :   4 | Score :  0 | Loss : 5001.195 | Mean scores of last 1000 episodes : 0.017
# Episode  1200 started -->  Total Transitions(Until end of this episode) :    3723 | Transitions(this episode) :   1 | Score :  0 | Loss : 9157.743 | Mean scores of last 1000 episodes : 0.018
# Episode  1400 started -->  Total Transitions(Until end of this episode) :    4368 | Transitions(this episode) :   5 | Score :  0 | Loss : 16585.086 | Mean scores of last 1000 episodes : 0.018
# Episode  1600 started -->  Total Transitions(Until end of this episode) :    5049 | Transitions(this episode) :   1 | Score :  0 | Loss : 27630.864 | Mean scores of last 1000 episodes : 0.021
# Episode  1800 started -->  Total Transitions(Until end of this episode) :    5643 | Transitions(this episode) :   5 | Score :  0 | Loss : 38543.078 | Mean scores of last 1000 episodes : 0.020
# Episode  2000 started -->  Total Transitions(Until end of this episode) :    6323 | Transitions(this episode) :   2 | Score :  0 | Loss : 31848.454 | Mean scores of last 1000 episodes : 0.026
# Episode  2200 started -->  Total Transitions(Until end of this episode) :    7004 | Transitions(this episode) :   3 | Score :  0 | Loss : 47606.330 | Mean scores of last 1000 episodes : 0.026
# Episode  2400 started -->  Total Transitions(Until end of this episode) :    7612 | Transitions(this episode) :   1 | Score :  0 | Loss : 44507.037 | Mean scores of last 1000 episodes : 0.023
# Episode  2600 started -->  Total Transitions(Until end of this episode) :    8299 | Transitions(this episode) :   5 | Score :  0 | Loss : 65196.120 | Mean scores of last 1000 episodes : 0.022
# Episode  2800 started -->  Total Transitions(Until end of this episode) :    8931 | Transitions(this episode) :   1 | Score :  0 | Loss : 82734.986 | Mean scores of last 1000 episodes : 0.027
# Episode  3000 started -->  Total Transitions(Until end of this episode) :    9614 | Transitions(this episode) :   2 | Score :  0 | Loss : 62264.610 | Mean scores of last 1000 episodes : 0.020
# Episode  3200 started -->  Total Transitions(Until end of this episode) :   10314 | Transitions(this episode) :   4 | Score :  0 | Loss : 64345.893 | Mean scores of last 1000 episodes : 0.023
# Episode  3400 started -->  Total Transitions(Until end of this episode) :   11003 | Transitions(this episode) :   2 | Score :  0 | Loss : 100455.661 | Mean scores of last 1000 episodes : 0.024
# Episode  3600 started -->  Total Transitions(Until end of this episode) :   11775 | Transitions(this episode) :   6 | Score :  0 | Loss : 102390.782 | Mean scores of last 1000 episodes : 0.027
# Episode  3800 started -->  Total Transitions(Until end of this episode) :   12466 | Transitions(this episode) :   5 | Score :  0 | Loss : 111904.770 | Mean scores of last 1000 episodes : 0.024
# Episode  4000 started -->  Total Transitions(Until end of this episode) :   13225 | Transitions(this episode) :   1 | Score :  0 | Loss : 74465.755 | Mean scores of last 1000 episodes : 0.029
# Episode  4200 started -->  Total Transitions(Until end of this episode) :   13946 | Transitions(this episode) :   4 | Score :  0 | Loss : 86688.907 | Mean scores of last 1000 episodes : 0.032
# Episode  4400 started -->  Total Transitions(Until end of this episode) :   14694 | Transitions(this episode) :   2 | Score :  0 | Loss : 115128.299 | Mean scores of last 1000 episodes : 0.037
# Episode  4600 started -->  Total Transitions(Until end of this episode) :   15445 | Transitions(this episode) :   4 | Score :  0 | Loss : 84439.114 | Mean scores of last 1000 episodes : 0.037
# Episode  4800 started -->  Total Transitions(Until end of this episode) :   16264 | Transitions(this episode) :   1 | Score :  0 | Loss : 88856.965 | Mean scores of last 1000 episodes : 0.042
# Episode  5000 started -->  Total Transitions(Until end of this episode) :   17007 | Transitions(this episode) :   1 | Score :  0 | Loss : 66614.087 | Mean scores of last 1000 episodes : 0.046
# Episode  5200 started -->  Total Transitions(Until end of this episode) :   17860 | Transitions(this episode) :   3 | Score :  0 | Loss : 75771.785 | Mean scores of last 1000 episodes : 0.047
# Episode  5400 started -->  Total Transitions(Until end of this episode) :   18691 | Transitions(this episode) :   2 | Score :  0 | Loss : 42621.214 | Mean scores of last 1000 episodes : 0.050
# Episode  5600 started -->  Total Transitions(Until end of this episode) :   19528 | Transitions(this episode) :   7 | Score :  0 | Loss : 86983.571 | Mean scores of last 1000 episodes : 0.052
# Episode  5800 started -->  Total Transitions(Until end of this episode) :   20420 | Transitions(this episode) :   4 | Score :  0 | Loss : 69166.768 | Mean scores of last 1000 episodes : 0.050
# Episode  6000 started -->  Total Transitions(Until end of this episode) :   21279 | Transitions(this episode) :   5 | Score :  0 | Loss : 75522.297 | Mean scores of last 1000 episodes : 0.052
# Episode  6200 started -->  Total Transitions(Until end of this episode) :   22066 | Transitions(this episode) :   2 | Score :  0 | Loss : 44318.651 | Mean scores of last 1000 episodes : 0.051
# Episode  6400 started -->  Total Transitions(Until end of this episode) :   22955 | Transitions(this episode) :   2 | Score :  0 | Loss : 38154.888 | Mean scores of last 1000 episodes : 0.053
# Episode  6600 started -->  Total Transitions(Until end of this episode) :   23783 | Transitions(this episode) :   2 | Score :  0 | Loss : 43239.149 | Mean scores of last 1000 episodes : 0.058
# Episode  6800 started -->  Total Transitions(Until end of this episode) :   24613 | Transitions(this episode) :   9 | Score :  0 | Loss : 61367.720 | Mean scores of last 1000 episodes : 0.058
# Episode  7000 started -->  Total Transitions(Until end of this episode) :   25490 | Transitions(this episode) :   2 | Score :  0 | Loss : 38893.967 | Mean scores of last 1000 episodes : 0.052
# Episode  7200 started -->  Total Transitions(Until end of this episode) :   26328 | Transitions(this episode) :   4 | Score :  0 | Loss : 59016.340 | Mean scores of last 1000 episodes : 0.052
# Episode  7400 started -->  Total Transitions(Until end of this episode) :   27248 | Transitions(this episode) :   1 | Score :  0 | Loss : 2509.029 | Mean scores of last 1000 episodes : 0.053
# Episode  7600 started -->  Total Transitions(Until end of this episode) :   28037 | Transitions(this episode) :   1 | Score :  0 | Loss : 29914.399 | Mean scores of last 1000 episodes : 0.056
# Episode  7800 started -->  Total Transitions(Until end of this episode) :   28945 | Transitions(this episode) :   3 | Score :  0 | Loss : 30275.793 | Mean scores of last 1000 episodes : 0.060
# Episode  8000 started -->  Total Transitions(Until end of this episode) :   29923 | Transitions(this episode) :   1 | Score :  0 | Loss : 28282.578 | Mean scores of last 1000 episodes : 0.069
# Episode  8200 started -->  Total Transitions(Until end of this episode) :   30813 | Transitions(this episode) :   1 | Score :  0 | Loss : 57041.816 | Mean scores of last 1000 episodes : 0.069
# Episode  8400 started -->  Total Transitions(Until end of this episode) :   31760 | Transitions(this episode) :   7 | Score :  0 | Loss : 35421.161 | Mean scores of last 1000 episodes : 0.071
# Episode  8600 started -->  Total Transitions(Until end of this episode) :   32701 | Transitions(this episode) :   1 | Score :  0 | Loss : 31129.424 | Mean scores of last 1000 episodes : 0.070
# Episode  8800 started -->  Total Transitions(Until end of this episode) :   33717 | Transitions(this episode) :   1 | Score :  0 | Loss : 19102.510 | Mean scores of last 1000 episodes : 0.081
# Episode  9000 started -->  Total Transitions(Until end of this episode) :   34648 | Transitions(this episode) :   6 | Score :  0 | Loss : 28670.622 | Mean scores of last 1000 episodes : 0.083
# Episode  9200 started -->  Total Transitions(Until end of this episode) :   35643 | Transitions(this episode) :   2 | Score :  0 | Loss : 73131.888 | Mean scores of last 1000 episodes : 0.096
# Episode  9400 started -->  Total Transitions(Until end of this episode) :   36787 | Transitions(this episode) :  12 | Score :  0 | Loss : 39134.676 | Mean scores of last 1000 episodes : 0.109
# Episode  9600 started -->  Total Transitions(Until end of this episode) :   37784 | Transitions(this episode) :   2 | Score :  0 | Loss : 46450.711 | Mean scores of last 1000 episodes : 0.114
# Episode  9800 started -->  Total Transitions(Until end of this episode) :   39015 | Transitions(this episode) :   1 | Score :  0 | Loss : 36185.157 | Mean scores of last 1000 episodes : 0.115
# Episode 10000 started -->  Total Transitions(Until end of this episode) :   40045 | Transitions(this episode) :   1 | Score :  0 | Loss : 30119.290 | Mean scores of last 1000 episodes : 0.116
# Episode 10200 started -->  Total Transitions(Until end of this episode) :   41137 | Transitions(this episode) :   3 | Score :  0 | Loss : 28006.399 | Mean scores of last 1000 episodes : 0.115
# Episode 10400 started -->  Total Transitions(Until end of this episode) :   42294 | Transitions(this episode) :   2 | Score :  0 | Loss : 26455.126 | Mean scores of last 1000 episodes : 0.121
# Episode 10600 started -->  Total Transitions(Until end of this episode) :   43454 | Transitions(this episode) :   1 | Score :  0 | Loss : 45721.111 | Mean scores of last 1000 episodes : 0.133
# Episode 10800 started -->  Total Transitions(Until end of this episode) :   44640 | Transitions(this episode) :   9 | Score :  0 | Loss : 22586.723 | Mean scores of last 1000 episodes : 0.140
# Episode 11000 started -->  Total Transitions(Until end of this episode) :   45670 | Transitions(this episode) :   1 | Score :  0 | Loss : 21386.863 | Mean scores of last 1000 episodes : 0.145
# Episode 11200 started -->  Total Transitions(Until end of this episode) :   46858 | Transitions(this episode) :   3 | Score :  0 | Loss : 30493.200 | Mean scores of last 1000 episodes : 0.159
# Episode 11400 started -->  Total Transitions(Until end of this episode) :   48011 | Transitions(this episode) :   3 | Score :  0 | Loss : 43691.435 | Mean scores of last 1000 episodes : 0.150
# Episode 11600 started -->  Total Transitions(Until end of this episode) :   49471 | Transitions(this episode) :   4 | Score :  0 | Loss : 29793.071 | Mean scores of last 1000 episodes : 0.165
# Episode 11800 started -->  Total Transitions(Until end of this episode) :   50789 | Transitions(this episode) :  14 | Score :  1 | Loss : 15586.406 | Mean scores of last 1000 episodes : 0.182
# Episode 12000 started -->  Total Transitions(Until end of this episode) :   52111 | Transitions(this episode) :  27 | Score :  1 | Loss : 4486.824 | Mean scores of last 1000 episodes : 0.204
# Episode 12200 started -->  Total Transitions(Until end of this episode) :   53507 | Transitions(this episode) :  16 | Score :  0 | Loss : 2505.604 | Mean scores of last 1000 episodes : 0.215
# Episode 12400 started -->  Total Transitions(Until end of this episode) :   54914 | Transitions(this episode) :   7 | Score :  0 | Loss : 2292.454 | Mean scores of last 1000 episodes : 0.237
# Episode 12600 started -->  Total Transitions(Until end of this episode) :   56529 | Transitions(this episode) :   5 | Score :  0 | Loss : 4325.065 | Mean scores of last 1000 episodes : 0.244
# Episode 12800 started -->  Total Transitions(Until end of this episode) :   58022 | Transitions(this episode) :   4 | Score :  0 | Loss : 5507.833 | Mean scores of last 1000 episodes : 0.255
# Episode 13000 started -->  Total Transitions(Until end of this episode) :   59432 | Transitions(this episode) :   2 | Score :  0 | Loss : 7749.941 | Mean scores of last 1000 episodes : 0.276
# Episode 13200 started -->  Total Transitions(Until end of this episode) :   61046 | Transitions(this episode) :   5 | Score :  1 | Loss : 4014.209 | Mean scores of last 1000 episodes : 0.316
# Episode 13400 started -->  Total Transitions(Until end of this episode) :   62766 | Transitions(this episode) :   6 | Score :  0 | Loss : 4609.661 | Mean scores of last 1000 episodes : 0.354
# Episode 13600 started -->  Total Transitions(Until end of this episode) :   64814 | Transitions(this episode) :   9 | Score :  0 | Loss : 9285.344 | Mean scores of last 1000 episodes : 0.405
# Episode 13800 started -->  Total Transitions(Until end of this episode) :   66825 | Transitions(this episode) :   6 | Score :  0 | Loss : 8731.637 | Mean scores of last 1000 episodes : 0.467
# Episode 14000 started -->  Total Transitions(Until end of this episode) :   68962 | Transitions(this episode) :   8 | Score :  0 | Loss : 4424.954 | Mean scores of last 1000 episodes : 0.527
# Episode 14200 started -->  Total Transitions(Until end of this episode) :   71295 | Transitions(this episode) :  13 | Score :  1 | Loss : 6896.143 | Mean scores of last 1000 episodes : 0.563
# Episode 14400 started -->  Total Transitions(Until end of this episode) :   73714 | Transitions(this episode) :  11 | Score :  1 | Loss : 6140.306 | Mean scores of last 1000 episodes : 0.622
# Episode 14600 started -->  Total Transitions(Until end of this episode) :   76172 | Transitions(this episode) :  10 | Score :  2 | Loss : 3753.104 | Mean scores of last 1000 episodes : 0.672
# Episode 14800 started -->  Total Transitions(Until end of this episode) :   78968 | Transitions(this episode) :  10 | Score :  0 | Loss : 9488.771 | Mean scores of last 1000 episodes : 0.745
# Episode 15000 started -->  Total Transitions(Until end of this episode) :   81783 | Transitions(this episode) :   8 | Score :  0 | Loss : 4334.045 | Mean scores of last 1000 episodes : 0.838
# Episode 15200 started -->  Total Transitions(Until end of this episode) :   85660 | Transitions(this episode) :   7 | Score :  1 | Loss : 5508.443 | Mean scores of last 1000 episodes : 1.020
# Episode 15400 started -->  Total Transitions(Until end of this episode) :   90654 | Transitions(this episode) :   2 | Score :  0 | Loss : 452.347 | Mean scores of last 1000 episodes : 1.349
# Episode 15600 started -->  Total Transitions(Until end of this episode) :  102303 | Transitions(this episode) :  89 | Score : 11 | Loss : 8064.385 | Mean scores of last 1000 episodes : 2.420
# Episode 15800 started -->  Total Transitions(Until end of this episode) :  133389 | Transitions(this episode) : 152 | Score : 17 | Loss : 14818.243 | Mean scores of last 1000 episodes : 5.527
# Episode 16000 started -->  Total Transitions(Until end of this episode) :  169791 | Transitions(this episode) : 190 | Score : 21 | Loss : 10876.563 | Mean scores of last 1000 episodes : 8.971
# Episode 16200 started -->  Total Transitions(Until end of this episode) :  207851 | Transitions(this episode) :  78 | Score :  9 | Loss : 9542.037 | Mean scores of last 1000 episodes : 12.487
# Episode 16400 started -->  Total Transitions(Until end of this episode) :  244474 | Transitions(this episode) : 176 | Score : 19 | Loss : 8615.024 | Mean scores of last 1000 episodes : 15.818
# Episode 16600 started -->  Total Transitions(Until end of this episode) :  282613 | Transitions(this episode) : 139 | Score : 13 | Loss : 6428.270 | Mean scores of last 1000 episodes : 18.350
# Episode 16800 started -->  Total Transitions(Until end of this episode) :  320612 | Transitions(this episode) : 179 | Score : 21 | Loss : 6110.070 | Mean scores of last 1000 episodes : 18.962
# Episode 17000 started -->  Total Transitions(Until end of this episode) :  360056 | Transitions(this episode) : 287 | Score : 26 | Loss : 5179.785 | Mean scores of last 1000 episodes : 19.134
# Episode 17200 started -->  Total Transitions(Until end of this episode) :  397600 | Transitions(this episode) : 216 | Score : 24 | Loss : 4856.016 | Mean scores of last 1000 episodes : 19.159
# Episode 17400 started -->  Total Transitions(Until end of this episode) :  434959 | Transitions(this episode) : 201 | Score : 23 | Loss : 4182.852 | Mean scores of last 1000 episodes : 19.346
# Episode 17600 started -->  Total Transitions(Until end of this episode) :  472883 | Transitions(this episode) : 190 | Score : 19 | Loss : 4085.624 | Mean scores of last 1000 episodes : 19.604
# Episode 17800 started -->  Total Transitions(Until end of this episode) :  508340 | Transitions(this episode) : 373 | Score : 30 | Loss : 3614.031 | Mean scores of last 1000 episodes : 19.515
# Episode 18000 started -->  Total Transitions(Until end of this episode) :  545217 | Transitions(this episode) : 274 | Score : 31 | Loss : 3688.720 | Mean scores of last 1000 episodes : 19.539
# Episode 18200 started -->  Total Transitions(Until end of this episode) :  581806 | Transitions(this episode) :  76 | Score : 10 | Loss : 3496.870 | Mean scores of last 1000 episodes : 19.497
# Episode 18400 started -->  Total Transitions(Until end of this episode) :  618857 | Transitions(this episode) :  73 | Score : 10 | Loss : 3632.613 | Mean scores of last 1000 episodes : 19.491
# Episode 18600 started -->  Total Transitions(Until end of this episode) :  654536 | Transitions(this episode) : 192 | Score : 19 | Loss : 3742.181 | Mean scores of last 1000 episodes : 19.292
# Episode 18800 started -->  Total Transitions(Until end of this episode) :  691331 | Transitions(this episode) : 112 | Score : 10 | Loss : 3530.846 | Mean scores of last 1000 episodes : 19.326
# Episode 19000 started -->  Total Transitions(Until end of this episode) :  723684 | Transitions(this episode) : 148 | Score : 19 | Loss : 4313.932 | Mean scores of last 1000 episodes : 18.967
# Episode 19200 started -->  Total Transitions(Until end of this episode) :  757956 | Transitions(this episode) : 105 | Score : 13 | Loss : 3938.182 | Mean scores of last 1000 episodes : 18.761
# Episode 19400 started -->  Total Transitions(Until end of this episode) :  793149 | Transitions(this episode) :  52 | Score :  6 | Loss : 3600.456 | Mean scores of last 1000 episodes : 18.560
# Episode 19600 started -->  Total Transitions(Until end of this episode) :  830081 | Transitions(this episode) : 125 | Score : 15 | Loss : 3571.285 | Mean scores of last 1000 episodes : 18.616
# Episode 19800 started -->  Total Transitions(Until end of this episode) :  863825 | Transitions(this episode) : 130 | Score : 15 | Loss : 3485.244 | Mean scores of last 1000 episodes : 18.497
# Episode 20000 started -->  Total Transitions(Until end of this episode) :  898447 | Transitions(this episode) : 191 | Score : 19 | Loss : 4067.926 | Mean scores of last 1000 episodes : 18.830
# Episode 20200 started -->  Total Transitions(Until end of this episode) :  934987 | Transitions(this episode) : 211 | Score : 20 | Loss : 3477.703 | Mean scores of last 1000 episodes : 19.166
# Episode 20400 started -->  Total Transitions(Until end of this episode) :  969926 | Transitions(this episode) : 126 | Score : 13 | Loss : 3464.588 | Mean scores of last 1000 episodes : 19.198
# Episode 20600 started -->  Total Transitions(Until end of this episode) : 1004516 | Transitions(this episode) :  89 | Score :  9 | Loss : 3497.666 | Mean scores of last 1000 episodes : 19.070
# Episode 20800 started -->  Total Transitions(Until end of this episode) : 1039281 | Transitions(this episode) :  83 | Score : 11 | Loss : 3344.390 | Mean scores of last 1000 episodes : 19.098
# Episode 21000 started -->  Total Transitions(Until end of this episode) : 1073303 | Transitions(this episode) : 178 | Score : 20 | Loss : 3661.300 | Mean scores of last 1000 episodes : 18.969
# Episode 21200 started -->  Total Transitions(Until end of this episode) : 1111048 | Transitions(this episode) : 400 | Score : 34 | Loss : 3528.200 | Mean scores of last 1000 episodes : 19.009
# Episode 21400 started -->  Total Transitions(Until end of this episode) : 1147686 | Transitions(this episode) :  81 | Score :  9 | Loss : 3244.320 | Mean scores of last 1000 episodes : 19.036
# Episode 21600 started -->  Total Transitions(Until end of this episode) : 1186382 | Transitions(this episode) : 293 | Score : 29 | Loss : 3257.524 | Mean scores of last 1000 episodes : 19.357
# Episode 21800 started -->  Total Transitions(Until end of this episode) : 1225344 | Transitions(this episode) : 166 | Score : 21 | Loss : 3082.336 | Mean scores of last 1000 episodes : 19.682
# Episode 22000 started -->  Total Transitions(Until end of this episode) : 1261114 | Transitions(this episode) : 188 | Score : 21 | Loss : 3437.835 | Mean scores of last 1000 episodes : 19.830
# Episode 22200 started -->  Total Transitions(Until end of this episode) : 1295360 | Transitions(this episode) : 189 | Score : 20 | Loss : 3719.792 | Mean scores of last 1000 episodes : 19.594
# Episode 22400 started -->  Total Transitions(Until end of this episode) : 1329422 | Transitions(this episode) : 179 | Score : 20 | Loss : 3583.462 | Mean scores of last 1000 episodes : 19.574
# Episode 22600 started -->  Total Transitions(Until end of this episode) : 1363346 | Transitions(this episode) : 181 | Score : 19 | Loss : 4400.461 | Mean scores of last 1000 episodes : 19.323
# Episode 22800 started -->  Total Transitions(Until end of this episode) : 1398837 | Transitions(this episode) : 150 | Score : 18 | Loss : 3910.257 | Mean scores of last 1000 episodes : 19.078
# Episode 23000 started -->  Total Transitions(Until end of this episode) : 1434623 | Transitions(this episode) :  86 | Score :  9 | Loss : 3799.346 | Mean scores of last 1000 episodes : 19.109
# Episode 23200 started -->  Total Transitions(Until end of this episode) : 1469896 | Transitions(this episode) : 282 | Score : 30 | Loss : 4032.663 | Mean scores of last 1000 episodes : 19.218
# Episode 23400 started -->  Total Transitions(Until end of this episode) : 1505453 | Transitions(this episode) : 235 | Score : 26 | Loss : 3808.358 | Mean scores of last 1000 episodes : 19.287
# Episode 23600 started -->  Total Transitions(Until end of this episode) : 1542142 | Transitions(this episode) :  90 | Score : 13 | Loss : 3739.813 | Mean scores of last 1000 episodes : 19.438
# Episode 23800 started -->  Total Transitions(Until end of this episode) : 1579720 | Transitions(this episode) : 141 | Score : 17 | Loss : 3439.656 | Mean scores of last 1000 episodes : 19.505
# Episode 24000 started -->  Total Transitions(Until end of this episode) : 1615787 | Transitions(this episode) : 241 | Score : 25 | Loss : 3557.286 | Mean scores of last 1000 episodes : 19.482
# Episode 24200 started -->  Total Transitions(Until end of this episode) : 1653863 | Transitions(this episode) : 108 | Score : 10 | Loss : 3791.420 | Mean scores of last 1000 episodes : 19.705
# Episode 24400 started -->  Total Transitions(Until end of this episode) : 1692207 | Transitions(this episode) : 165 | Score : 19 | Loss : 3675.837 | Mean scores of last 1000 episodes : 19.734
# Episode 24600 started -->  Total Transitions(Until end of this episode) : 1730342 | Transitions(this episode) : 198 | Score : 21 | Loss : 3308.403 | Mean scores of last 1000 episodes : 19.763
# Episode 24800 started -->  Total Transitions(Until end of this episode) : 1764745 | Transitions(this episode) : 130 | Score : 15 | Loss : 3909.331 | Mean scores of last 1000 episodes : 19.521
# Episode 25000 started -->  Total Transitions(Until end of this episode) : 1802394 | Transitions(this episode) : 217 | Score : 22 | Loss : 3957.485 | Mean scores of last 1000 episodes : 19.547
# Episode 25200 started -->  Total Transitions(Until end of this episode) : 1838852 | Transitions(this episode) : 113 | Score : 12 | Loss : 3650.803 | Mean scores of last 1000 episodes : 19.282
# Episode 25400 started -->  Total Transitions(Until end of this episode) : 1874700 | Transitions(this episode) : 208 | Score : 25 | Loss : 3443.684 | Mean scores of last 1000 episodes : 19.173
# Episode 25600 started -->  Total Transitions(Until end of this episode) : 1911513 | Transitions(this episode) :  22 | Score :  4 | Loss : 3901.556 | Mean scores of last 1000 episodes : 19.024
# Episode 25800 started -->  Total Transitions(Until end of this episode) : 1951646 | Transitions(this episode) :  76 | Score : 10 | Loss : 3455.029 | Mean scores of last 1000 episodes : 19.497
# Episode 26000 started -->  Total Transitions(Until end of this episode) : 1986768 | Transitions(this episode) : 113 | Score : 14 | Loss : 3724.236 | Mean scores of last 1000 episodes : 19.333
# Episode 26200 started -->  Total Transitions(Until end of this episode) : 2022332 | Transitions(this episode) : 225 | Score : 21 | Loss : 3872.808 | Mean scores of last 1000 episodes : 19.360
# Episode 26400 started -->  Total Transitions(Until end of this episode) : 2057594 | Transitions(this episode) :  89 | Score : 10 | Loss : 3800.442 | Mean scores of last 1000 episodes : 19.406
# Episode 26600 started -->  Total Transitions(Until end of this episode) : 2093072 | Transitions(this episode) : 228 | Score : 22 | Loss : 3837.146 | Mean scores of last 1000 episodes : 19.330
# Episode 26800 started -->  Total Transitions(Until end of this episode) : 2128533 | Transitions(this episode) : 245 | Score : 22 | Loss : 3624.445 | Mean scores of last 1000 episodes : 18.994
# Episode 27000 started -->  Total Transitions(Until end of this episode) : 2163437 | Transitions(this episode) : 171 | Score : 19 | Loss : 4147.083 | Mean scores of last 1000 episodes : 18.975
# Episode 27200 started -->  Total Transitions(Until end of this episode) : 2202889 | Transitions(this episode) :  85 | Score : 11 | Loss : 3493.871 | Mean scores of last 1000 episodes : 19.224
# Episode 27400 started -->  Total Transitions(Until end of this episode) : 2241881 | Transitions(this episode) : 248 | Score : 25 | Loss : 3174.832 | Mean scores of last 1000 episodes : 19.443
# Episode 27600 started -->  Total Transitions(Until end of this episode) : 2278057 | Transitions(this episode) : 401 | Score : 35 | Loss : 3583.397 | Mean scores of last 1000 episodes : 19.458
# Episode 27800 started -->  Total Transitions(Until end of this episode) : 2317088 | Transitions(this episode) : 237 | Score : 24 | Loss : 3195.852 | Mean scores of last 1000 episodes : 19.703
# Episode 28000 started -->  Total Transitions(Until end of this episode) : 2353497 | Transitions(this episode) : 113 | Score : 14 | Loss : 3388.229 | Mean scores of last 1000 episodes : 19.835
# Episode 28200 started -->  Total Transitions(Until end of this episode) : 2389077 | Transitions(this episode) :  97 | Score : 12 | Loss : 3735.316 | Mean scores of last 1000 episodes : 19.533
# Episode 28400 started -->  Total Transitions(Until end of this episode) : 2425643 | Transitions(this episode) : 226 | Score : 22 | Loss : 3382.392 | Mean scores of last 1000 episodes : 19.405
# Episode 28600 started -->  Total Transitions(Until end of this episode) : 2461178 | Transitions(this episode) : 189 | Score : 19 | Loss : 3997.623 | Mean scores of last 1000 episodes : 19.427
# Episode 28800 started -->  Total Transitions(Until end of this episode) : 2494975 | Transitions(this episode) : 235 | Score : 29 | Loss : 4092.260 | Mean scores of last 1000 episodes : 19.065
# Episode 29000 started -->  Total Transitions(Until end of this episode) : 2529637 | Transitions(this episode) : 124 | Score : 14 | Loss : 3111.181 | Mean scores of last 1000 episodes : 18.898
# Episode 29200 started -->  Total Transitions(Until end of this episode) : 2566618 | Transitions(this episode) : 224 | Score : 26 | Loss : 3218.473 | Mean scores of last 1000 episodes : 19.001
# Episode 29400 started -->  Total Transitions(Until end of this episode) : 2602384 | Transitions(this episode) : 300 | Score : 31 | Loss : 3193.675 | Mean scores of last 1000 episodes : 18.878
# Episode 29600 started -->  Total Transitions(Until end of this episode) : 2636484 | Transitions(this episode) : 335 | Score : 30 | Loss : 3397.147 | Mean scores of last 1000 episodes : 18.771
# Episode 29800 started -->  Total Transitions(Until end of this episode) : 2671694 | Transitions(this episode) : 107 | Score : 13 | Loss : 3279.018 | Mean scores of last 1000 episodes : 18.887
# Episode 30000 started -->  Total Transitions(Until end of this episode) : 2709065 | Transitions(this episode) : 137 | Score : 15 | Loss : 3424.654 | Mean scores of last 1000 episodes : 19.168
# **** Finished in ~ 209 Minutes

# %%
# Plot the scores
x = [i for i in range(1,M+1)]
y = scores
plt.plot(x,y)
plt.title("Scores of {} episodes (Train)".format(M))
plt.xlabel("Episode")
plt.ylabel("Score")
plt.show()
