# %%
# Import Packages
import time,os
import torch
import numpy as np 
import matplotlib.pyplot as plt
import torch.cuda as cuda
import pickle
from tensorflow.python.client import device_lib
from google.colab import drive
from IPython.display import clear_output

# Import My Modules 
from snake_class import Agent 
from food_class import meal, food_init
from network import net


features = 8 # Number of features
episodes = 1000 # Number pf Episodes
dimension = 10 + 2
action_to_direction = {0:"Left" , 1:"Right", 2:"Up", 3:"Down"}
scores = []

##### THESE VARIABLES ARE NOT USED DURING THE TEST TIME ##########
ep_min = None
delta_ep = None
e = None 
memory = None
batch_size = None
Q_target = None
gamma = None
####################################################################



print(device_lib.list_local_devices()) # Show the GPU & CPU Specifications
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1278914956675447259
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 88769202510644025
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 10467115938192593434
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14618221632
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 2247550684555679923
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %%
# Network

Q_policy=net(features,4) # Q_theta
Q_policy.eval()
Q_policy.double()

PATH="./Model/policy_network.pth"
checkpoint = torch.load(PATH)
Q_policy.load_state_dict(checkpoint['Q_policy_state_dict'])
if cuda.is_available():
          Q_policy = Q_policy.cuda()

# %%
# Test

from functions import return_state

for episode in range(1, episodes+1):
    print("Episode {0:4d} started --->".format(episode),end="  ")
    loose = False
    step = 0
    snake= Agent(dimension)
    food,_ = food_init(dimension,snake.path)    
    current_state = return_state(snake.path , food)  #  np array ([4, features])  
    score = 0 
    while loose != True: # Not loose
       
        tensor_current_state = torch.from_numpy(current_state)
        if cuda.is_available():
          tensor_current_state = tensor_current_state.cuda()
        
        Q_policy.eval()
        with torch.no_grad():
          out = Q_policy(tensor_current_state)

        best_action = int(torch.argmax( out ))
        action = best_action # action is 0, 1, 2 or 3 

        snake.move(action_to_direction[action],dimension)
        step += 1

        if snake.head[0] == food.x and snake.head[1] == food.y:  # Eating food
            score += 1
            food, isFinished = food_init(dimension,snake.path) # Initializing the food position
            loose = isFinished
            new_state = return_state(snake.path,food)  #  np array ([1, features])  

   
        elif snake.head in snake.path[1:-1]: # Loose : runs into itself
            loose = True
            snake.path.pop(0) # Removing the tail
            new_state = return_state(snake.path , food)  #  np array ([1, features])  
            scores.append(score)
           
            
        elif (snake.head[0] in [0,dimension-1]) or (snake.head[1] in [0,dimension-1]): # Loose : runs into the wall
            loose = True
            snake.path.pop(0) # Removing the tail
            new_state = return_state(snake.path , food)  #  np array ([1, features])  
            scores.append(score)
        
        else : # Just moved
            snake.path.pop(0) # Removing the tail
            new_state = return_state(snake.path , food)  #  np array ([1, features])  

        current_state = new_state.copy()
        
        if (loose == True) :
              print("Transitions : {0:3d}".format(step),end=" | ")
              print("Score : {0:3d}".format(score))

print("____________________________________________________")
print("Results of {} episode:".format(episodes))
print("Mean(socres) = {}".format(np.mean(scores)))
print("std(socres) = {}".format(np.std(scores)))
print("Max(socres) = {}".format(np.max(scores)))

x = [i for i in range(1,episodes+1)]
y = scores
plt.plot(x,y)
plt.title("Scores of {} episodes (Test)".format(episodes))
plt.xlabel("Episode")
plt.ylabel("Score")
plt.show()
# Out:
# Episode    1 started --->  Transitions :  86 | Score :  11
# Episode    2 started --->  Transitions : 311 | Score :  34
# Episode    3 started --->  Transitions : 219 | Score :  25
# Episode    4 started --->  Transitions : 184 | Score :  19
# Episode    5 started --->  Transitions : 173 | Score :  19
# Episode    6 started --->  Transitions : 109 | Score :  15
# Episode    7 started --->  Transitions : 173 | Score :  20
# Episode    8 started --->  Transitions : 147 | Score :  18
# Episode    9 started --->  Transitions : 441 | Score :  41
# Episode   10 started --->  Transitions : 448 | Score :  38
# Episode   11 started --->  Transitions :  66 | Score :   6
# Episode   12 started --->  Transitions : 201 | Score :  21
# Episode   13 started --->  Transitions : 111 | Score :  16
# Episode   14 started --->  Transitions : 222 | Score :  25
# Episode   15 started --->  Transitions : 291 | Score :  31
# Episode   16 started --->  Transitions : 137 | Score :  13
# Episode   17 started --->  Transitions : 164 | Score :  18
# Episode   18 started --->  Transitions : 314 | Score :  32
# Episode   19 started --->  Transitions :  75 | Score :  10
# Episode   20 started --->  Transitions : 198 | Score :  20
# Episode   21 started --->  Transitions : 119 | Score :  15
# Episode   22 started --->  Transitions : 213 | Score :  21
# Episode   23 started --->  Transitions :  76 | Score :  11
# Episode   24 started --->  Transitions : 191 | Score :  25
# Episode   25 started --->  Transitions : 141 | Score :  15
# Episode   26 started --->  Transitions : 217 | Score :  23
# Episode   27 started --->  Transitions :  95 | Score :  11
# Episode   28 started --->  Transitions : 255 | Score :  24
# Episode   29 started --->  Transitions : 175 | Score :  15
# Episode   30 started --->  Transitions : 168 | Score :  19
# Episode   31 started --->  Transitions : 193 | Score :  20
# Episode   32 started --->  Transitions : 117 | Score :  16
# Episode   33 started --->  Transitions :  17 | Score :   2
# Episode   34 started --->  Transitions : 200 | Score :  22
# Episode   35 started --->  Transitions : 130 | Score :  17
# Episode   36 started --->  Transitions : 171 | Score :  18
# Episode   37 started --->  Transitions : 336 | Score :  25
# Episode   38 started --->  Transitions : 246 | Score :  24
# Episode   39 started --->  Transitions : 190 | Score :  19
# Episode   40 started --->  Transitions :  98 | Score :  12
# Episode   41 started --->  Transitions : 218 | Score :  20
# Episode   42 started --->  Transitions : 174 | Score :  18
# Episode   43 started --->  Transitions : 260 | Score :  26
# Episode   44 started --->  Transitions : 198 | Score :  22
# Episode   45 started --->  Transitions : 149 | Score :  18
# Episode   46 started --->  Transitions : 235 | Score :  20
# Episode   47 started --->  Transitions : 289 | Score :  27
# Episode   48 started --->  Transitions : 221 | Score :  20
# Episode   49 started --->  Transitions : 248 | Score :  27
# Episode   50 started --->  Transitions : 196 | Score :  21
# Episode   51 started --->  Transitions : 222 | Score :  27
# Episode   52 started --->  Transitions : 123 | Score :  16
# Episode   53 started --->  Transitions :  88 | Score :  15
# Episode   54 started --->  Transitions : 263 | Score :  31
# Episode   55 started --->  Transitions :  95 | Score :  12
# Episode   56 started --->  Transitions : 111 | Score :  13
# Episode   57 started --->  Transitions : 143 | Score :  13
# Episode   58 started --->  Transitions : 159 | Score :  23
# Episode   59 started --->  Transitions : 120 | Score :  11
# Episode   60 started --->  Transitions : 297 | Score :  28
# Episode   61 started --->  Transitions : 160 | Score :  16
# Episode   62 started --->  Transitions :  80 | Score :   9
# Episode   63 started --->  Transitions : 264 | Score :  27
# Episode   64 started --->  Transitions : 177 | Score :  18
# Episode   65 started --->  Transitions :  91 | Score :  10
# Episode   66 started --->  Transitions : 107 | Score :  11
# Episode   67 started --->  Transitions : 130 | Score :  17
# Episode   68 started --->  Transitions : 148 | Score :  16
# Episode   69 started --->  Transitions : 144 | Score :  17
# Episode   70 started --->  Transitions : 228 | Score :  23
# Episode   71 started --->  Transitions : 187 | Score :  19
# Episode   72 started --->  Transitions : 148 | Score :  14
# Episode   73 started --->  Transitions : 292 | Score :  30
# Episode   74 started --->  Transitions : 311 | Score :  28
# Episode   75 started --->  Transitions :  52 | Score :  10
# Episode   76 started --->  Transitions : 119 | Score :  11
# Episode   77 started --->  Transitions : 174 | Score :  18
# Episode   78 started --->  Transitions : 120 | Score :  14
# Episode   79 started --->  Transitions :  99 | Score :  11
# Episode   80 started --->  Transitions : 253 | Score :  23
# Episode   81 started --->  Transitions : 195 | Score :  20
# Episode   82 started --->  Transitions : 181 | Score :  19
# Episode   83 started --->  Transitions : 329 | Score :  33
# Episode   84 started --->  Transitions : 204 | Score :  19
# Episode   85 started --->  Transitions : 299 | Score :  29
# Episode   86 started --->  Transitions : 343 | Score :  31
# Episode   87 started --->  Transitions : 380 | Score :  31
# Episode   88 started --->  Transitions : 239 | Score :  27
# Episode   89 started --->  Transitions : 243 | Score :  26
# Episode   90 started --->  Transitions : 362 | Score :  34
# Episode   91 started --->  Transitions : 281 | Score :  24
# Episode   92 started --->  Transitions : 283 | Score :  29
# Episode   93 started --->  Transitions : 122 | Score :  13
# Episode   94 started --->  Transitions : 206 | Score :  24
# Episode   95 started --->  Transitions : 177 | Score :  19
# Episode   96 started --->  Transitions : 357 | Score :  33
# Episode   97 started --->  Transitions : 161 | Score :  19
# Episode   98 started --->  Transitions : 164 | Score :  22
# Episode   99 started --->  Transitions : 196 | Score :  18
# Episode  100 started --->  Transitions :  84 | Score :  12
# Episode  101 started --->  Transitions : 152 | Score :  18
# Episode  102 started --->  Transitions : 160 | Score :  19
# Episode  103 started --->  Transitions : 137 | Score :  14
# Episode  104 started --->  Transitions : 114 | Score :  13
# Episode  105 started --->  Transitions : 288 | Score :  29
# Episode  106 started --->  Transitions : 190 | Score :  18
# Episode  107 started --->  Transitions : 145 | Score :  13
# Episode  108 started --->  Transitions : 332 | Score :  29
# Episode  109 started --->  Transitions : 119 | Score :  14
# Episode  110 started --->  Transitions : 209 | Score :  21
# Episode  111 started --->  Transitions : 172 | Score :  17
# Episode  112 started --->  Transitions : 126 | Score :  16
# Episode  113 started --->  Transitions : 206 | Score :  20
# Episode  114 started --->  Transitions : 141 | Score :  16
# Episode  115 started --->  Transitions : 182 | Score :  17
# Episode  116 started --->  Transitions : 130 | Score :  14
# Episode  117 started --->  Transitions :  90 | Score :  11
# Episode  118 started --->  Transitions : 170 | Score :  20
# Episode  119 started --->  Transitions : 217 | Score :  24
# Episode  120 started --->  Transitions : 129 | Score :  14
# Episode  121 started --->  Transitions :  39 | Score :   5
# Episode  122 started --->  Transitions : 167 | Score :  16
# Episode  123 started --->  Transitions : 245 | Score :  22
# Episode  124 started --->  Transitions : 270 | Score :  29
# Episode  125 started --->  Transitions : 209 | Score :  23
# Episode  126 started --->  Transitions : 373 | Score :  36
# Episode  127 started --->  Transitions : 353 | Score :  30
# Episode  128 started --->  Transitions :  99 | Score :  14
# Episode  129 started --->  Transitions :  75 | Score :  10
# Episode  130 started --->  Transitions : 242 | Score :  28
# Episode  131 started --->  Transitions : 241 | Score :  23
# Episode  132 started --->  Transitions : 147 | Score :  16
# Episode  133 started --->  Transitions :  61 | Score :   7
# Episode  134 started --->  Transitions : 127 | Score :  15
# Episode  135 started --->  Transitions :  46 | Score :   8
# Episode  136 started --->  Transitions : 129 | Score :  13
# Episode  137 started --->  Transitions : 229 | Score :  22
# Episode  138 started --->  Transitions :  15 | Score :   3
# Episode  139 started --->  Transitions : 294 | Score :  32
# Episode  140 started --->  Transitions :  64 | Score :   8
# Episode  141 started --->  Transitions : 307 | Score :  26
# Episode  142 started --->  Transitions : 275 | Score :  31
# Episode  143 started --->  Transitions : 251 | Score :  26
# Episode  144 started --->  Transitions : 337 | Score :  30
# Episode  145 started --->  Transitions : 186 | Score :  19
# Episode  146 started --->  Transitions : 152 | Score :  18
# Episode  147 started --->  Transitions : 145 | Score :  14
# Episode  148 started --->  Transitions : 239 | Score :  22
# Episode  149 started --->  Transitions : 164 | Score :  20
# Episode  150 started --->  Transitions : 242 | Score :  22
# Episode  151 started --->  Transitions : 161 | Score :  17
# Episode  152 started --->  Transitions : 207 | Score :  21
# Episode  153 started --->  Transitions : 252 | Score :  24
# Episode  154 started --->  Transitions : 207 | Score :  21
# Episode  155 started --->  Transitions : 105 | Score :  12
# Episode  156 started --->  Transitions : 139 | Score :  16
# Episode  157 started --->  Transitions : 130 | Score :  17
# Episode  158 started --->  Transitions : 215 | Score :  22
# Episode  159 started --->  Transitions : 246 | Score :  23
# Episode  160 started --->  Transitions : 180 | Score :  20
# Episode  161 started --->  Transitions : 119 | Score :  14
# Episode  162 started --->  Transitions : 189 | Score :  19
# Episode  163 started --->  Transitions : 292 | Score :  30
# Episode  164 started --->  Transitions : 113 | Score :  12
# Episode  165 started --->  Transitions : 148 | Score :  14
# Episode  166 started --->  Transitions : 232 | Score :  25
# Episode  167 started --->  Transitions : 267 | Score :  27
# Episode  168 started --->  Transitions : 351 | Score :  27
# Episode  169 started --->  Transitions : 116 | Score :  15
# Episode  170 started --->  Transitions :  99 | Score :  12
# Episode  171 started --->  Transitions : 138 | Score :  17
# Episode  172 started --->  Transitions : 154 | Score :  17
# Episode  173 started --->  Transitions : 153 | Score :  16
# Episode  174 started --->  Transitions : 122 | Score :  15
# Episode  175 started --->  Transitions : 251 | Score :  24
# Episode  176 started --->  Transitions : 117 | Score :  13
# Episode  177 started --->  Transitions : 248 | Score :  22
# Episode  178 started --->  Transitions : 293 | Score :  29
# Episode  179 started --->  Transitions : 182 | Score :  19
# Episode  180 started --->  Transitions : 207 | Score :  21
# Episode  181 started --->  Transitions : 143 | Score :  16
# Episode  182 started --->  Transitions : 213 | Score :  21
# Episode  183 started --->  Transitions : 174 | Score :  19
# Episode  184 started --->  Transitions : 166 | Score :  19
# Episode  185 started --->  Transitions : 178 | Score :  19
# Episode  186 started --->  Transitions : 213 | Score :  19
# Episode  187 started --->  Transitions : 279 | Score :  27
# Episode  188 started --->  Transitions : 151 | Score :  18
# Episode  189 started --->  Transitions : 179 | Score :  20
# Episode  190 started --->  Transitions : 131 | Score :  13
# Episode  191 started --->  Transitions : 220 | Score :  23
# Episode  192 started --->  Transitions :  37 | Score :   5
# Episode  193 started --->  Transitions : 319 | Score :  33
# Episode  194 started --->  Transitions : 228 | Score :  22
# Episode  195 started --->  Transitions : 210 | Score :  23
# Episode  196 started --->  Transitions :  71 | Score :   9
# Episode  197 started --->  Transitions :  74 | Score :  10
# Episode  198 started --->  Transitions : 104 | Score :  11
# Episode  199 started --->  Transitions : 264 | Score :  29
# Episode  200 started --->  Transitions : 179 | Score :  19
# Episode  201 started --->  Transitions : 118 | Score :  13
# Episode  202 started --->  Transitions : 107 | Score :  13
# Episode  203 started --->  Transitions : 128 | Score :  16
# Episode  204 started --->  Transitions : 221 | Score :  25
# Episode  205 started --->  Transitions : 387 | Score :  37
# Episode  206 started --->  Transitions : 299 | Score :  25
# Episode  207 started --->  Transitions : 141 | Score :  19
# Episode  208 started --->  Transitions : 131 | Score :  16
# Episode  209 started --->  Transitions : 136 | Score :  13
# Episode  210 started --->  Transitions : 223 | Score :  26
# Episode  211 started --->  Transitions : 322 | Score :  32
# Episode  212 started --->  Transitions : 223 | Score :  22
# Episode  213 started --->  Transitions : 170 | Score :  14
# Episode  214 started --->  Transitions : 163 | Score :  17
# Episode  215 started --->  Transitions : 100 | Score :  14
# Episode  216 started --->  Transitions : 345 | Score :  26
# Episode  217 started --->  Transitions : 130 | Score :  15
# Episode  218 started --->  Transitions :  37 | Score :   6
# Episode  219 started --->  Transitions : 305 | Score :  28
# Episode  220 started --->  Transitions : 316 | Score :  32
# Episode  221 started --->  Transitions : 157 | Score :  19
# Episode  222 started --->  Transitions : 222 | Score :  22
# Episode  223 started --->  Transitions : 198 | Score :  21
# Episode  224 started --->  Transitions : 302 | Score :  27
# Episode  225 started --->  Transitions : 404 | Score :  32
# Episode  226 started --->  Transitions : 208 | Score :  21
# Episode  227 started --->  Transitions : 126 | Score :  13
# Episode  228 started --->  Transitions : 325 | Score :  30
# Episode  229 started --->  Transitions : 136 | Score :  16
# Episode  230 started --->  Transitions :  98 | Score :  13
# Episode  231 started --->  Transitions : 143 | Score :  19
# Episode  232 started --->  Transitions : 164 | Score :  19
# Episode  233 started --->  Transitions :  98 | Score :  10
# Episode  234 started --->  Transitions : 162 | Score :  17
# Episode  235 started --->  Transitions : 163 | Score :  16
# Episode  236 started --->  Transitions : 205 | Score :  22
# Episode  237 started --->  Transitions : 325 | Score :  28
# Episode  238 started --->  Transitions : 258 | Score :  24
# Episode  239 started --->  Transitions : 343 | Score :  29
# Episode  240 started --->  Transitions : 224 | Score :  22
# Episode  241 started --->  Transitions : 274 | Score :  28
# Episode  242 started --->  Transitions : 211 | Score :  23
# Episode  243 started --->  Transitions : 170 | Score :  21
# Episode  244 started --->  Transitions : 183 | Score :  22
# Episode  245 started --->  Transitions : 189 | Score :  22
# Episode  246 started --->  Transitions : 274 | Score :  29
# Episode  247 started --->  Transitions : 224 | Score :  24
# Episode  248 started --->  Transitions :  55 | Score :   7
# Episode  249 started --->  Transitions :  78 | Score :  10
# Episode  250 started --->  Transitions : 259 | Score :  24
# Episode  251 started --->  Transitions : 196 | Score :  22
# Episode  252 started --->  Transitions : 163 | Score :  18
# Episode  253 started --->  Transitions : 229 | Score :  22
# Episode  254 started --->  Transitions : 266 | Score :  29
# Episode  255 started --->  Transitions : 175 | Score :  19
# Episode  256 started --->  Transitions : 325 | Score :  31
# Episode  257 started --->  Transitions : 100 | Score :  11
# Episode  258 started --->  Transitions : 234 | Score :  25
# Episode  259 started --->  Transitions : 162 | Score :  18
# Episode  260 started --->  Transitions : 255 | Score :  25
# Episode  261 started --->  Transitions : 232 | Score :  23
# Episode  262 started --->  Transitions : 173 | Score :  20
# Episode  263 started --->  Transitions : 200 | Score :  20
# Episode  264 started --->  Transitions : 242 | Score :  24
# Episode  265 started --->  Transitions : 195 | Score :  19
# Episode  266 started --->  Transitions : 130 | Score :  11
# Episode  267 started --->  Transitions : 371 | Score :  34
# Episode  268 started --->  Transitions : 431 | Score :  39
# Episode  269 started --->  Transitions : 394 | Score :  36
# Episode  270 started --->  Transitions : 204 | Score :  20
# Episode  271 started --->  Transitions :  54 | Score :   9
# Episode  272 started --->  Transitions : 254 | Score :  22
# Episode  273 started --->  Transitions : 106 | Score :  11
# Episode  274 started --->  Transitions : 206 | Score :  22
# Episode  275 started --->  Transitions : 175 | Score :  23
# Episode  276 started --->  Transitions : 178 | Score :  21
# Episode  277 started --->  Transitions :  67 | Score :   9
# Episode  278 started --->  Transitions : 116 | Score :  13
# Episode  279 started --->  Transitions : 230 | Score :  25
# Episode  280 started --->  Transitions : 178 | Score :  19
# Episode  281 started --->  Transitions : 363 | Score :  35
# Episode  282 started --->  Transitions : 114 | Score :  10
# Episode  283 started --->  Transitions : 197 | Score :  26
# Episode  284 started --->  Transitions : 246 | Score :  27
# Episode  285 started --->  Transitions : 188 | Score :  18
# Episode  286 started --->  Transitions : 287 | Score :  33
# Episode  287 started --->  Transitions : 212 | Score :  19
# Episode  288 started --->  Transitions : 192 | Score :  26
# Episode  289 started --->  Transitions : 275 | Score :  22
# Episode  290 started --->  Transitions : 182 | Score :  19
# Episode  291 started --->  Transitions : 208 | Score :  21
# Episode  292 started --->  Transitions : 211 | Score :  20
# Episode  293 started --->  Transitions : 163 | Score :  17
# Episode  294 started --->  Transitions :  58 | Score :   8
# Episode  295 started --->  Transitions : 216 | Score :  16
# Episode  296 started --->  Transitions : 333 | Score :  28
# Episode  297 started --->  Transitions : 277 | Score :  25
# Episode  298 started --->  Transitions : 211 | Score :  21
# Episode  299 started --->  Transitions : 101 | Score :  12
# Episode  300 started --->  Transitions : 247 | Score :  24
# Episode  301 started --->  Transitions : 409 | Score :  31
# Episode  302 started --->  Transitions : 184 | Score :  22
# Episode  303 started --->  Transitions : 192 | Score :  22
# Episode  304 started --->  Transitions : 245 | Score :  24
# Episode  305 started --->  Transitions : 187 | Score :  21
# Episode  306 started --->  Transitions : 172 | Score :  16
# Episode  307 started --->  Transitions : 297 | Score :  28
# Episode  308 started --->  Transitions : 146 | Score :  17
# Episode  309 started --->  Transitions : 254 | Score :  26
# Episode  310 started --->  Transitions : 220 | Score :  24
# Episode  311 started --->  Transitions : 133 | Score :  14
# Episode  312 started --->  Transitions : 119 | Score :  13
# Episode  313 started --->  Transitions : 219 | Score :  23
# Episode  314 started --->  Transitions : 249 | Score :  26
# Episode  315 started --->  Transitions : 201 | Score :  24
# Episode  316 started --->  Transitions : 168 | Score :  20
# Episode  317 started --->  Transitions : 200 | Score :  19
# Episode  318 started --->  Transitions : 118 | Score :  13
# Episode  319 started --->  Transitions : 242 | Score :  25
# Episode  320 started --->  Transitions : 185 | Score :  16
# Episode  321 started --->  Transitions : 184 | Score :  23
# Episode  322 started --->  Transitions : 186 | Score :  17
# Episode  323 started --->  Transitions : 169 | Score :  19
# Episode  324 started --->  Transitions : 129 | Score :  14
# Episode  325 started --->  Transitions : 178 | Score :  19
# Episode  326 started --->  Transitions : 198 | Score :  21
# Episode  327 started --->  Transitions : 229 | Score :  24
# Episode  328 started --->  Transitions : 161 | Score :  17
# Episode  329 started --->  Transitions : 515 | Score :  39
# Episode  330 started --->  Transitions : 113 | Score :  15
# Episode  331 started --->  Transitions : 109 | Score :  11
# Episode  332 started --->  Transitions : 108 | Score :  13
# Episode  333 started --->  Transitions : 150 | Score :  17
# Episode  334 started --->  Transitions :  91 | Score :  11
# Episode  335 started --->  Transitions : 157 | Score :  20
# Episode  336 started --->  Transitions : 247 | Score :  24
# Episode  337 started --->  Transitions : 223 | Score :  23
# Episode  338 started --->  Transitions :  69 | Score :   9
# Episode  339 started --->  Transitions : 244 | Score :  22
# Episode  340 started --->  Transitions : 137 | Score :  15
# Episode  341 started --->  Transitions : 182 | Score :  22
# Episode  342 started --->  Transitions : 117 | Score :  14
# Episode  343 started --->  Transitions :  92 | Score :  11
# Episode  344 started --->  Transitions : 203 | Score :  19
# Episode  345 started --->  Transitions : 278 | Score :  29
# Episode  346 started --->  Transitions :  81 | Score :  15
# Episode  347 started --->  Transitions : 175 | Score :  19
# Episode  348 started --->  Transitions : 158 | Score :  15
# Episode  349 started --->  Transitions : 152 | Score :  16
# Episode  350 started --->  Transitions : 198 | Score :  22
# Episode  351 started --->  Transitions :  63 | Score :   8
# Episode  352 started --->  Transitions : 251 | Score :  24
# Episode  353 started --->  Transitions : 214 | Score :  20
# Episode  354 started --->  Transitions : 216 | Score :  27
# Episode  355 started --->  Transitions : 216 | Score :  24
# Episode  356 started --->  Transitions : 247 | Score :  25
# Episode  357 started --->  Transitions : 225 | Score :  22
# Episode  358 started --->  Transitions : 172 | Score :  19
# Episode  359 started --->  Transitions : 246 | Score :  23
# Episode  360 started --->  Transitions : 210 | Score :  22
# Episode  361 started --->  Transitions : 210 | Score :  23
# Episode  362 started --->  Transitions : 216 | Score :  21
# Episode  363 started --->  Transitions :  48 | Score :   5
# Episode  364 started --->  Transitions : 237 | Score :  25
# Episode  365 started --->  Transitions : 189 | Score :  23
# Episode  366 started --->  Transitions : 113 | Score :  13
# Episode  367 started --->  Transitions : 260 | Score :  23
# Episode  368 started --->  Transitions : 236 | Score :  24
# Episode  369 started --->  Transitions : 201 | Score :  20
# Episode  370 started --->  Transitions : 218 | Score :  24
# Episode  371 started --->  Transitions : 128 | Score :  16
# Episode  372 started --->  Transitions : 311 | Score :  26
# Episode  373 started --->  Transitions : 314 | Score :  29
# Episode  374 started --->  Transitions : 104 | Score :  15
# Episode  375 started --->  Transitions : 256 | Score :  27
# Episode  376 started --->  Transitions : 267 | Score :  32
# Episode  377 started --->  Transitions : 243 | Score :  26
# Episode  378 started --->  Transitions : 174 | Score :  21
# Episode  379 started --->  Transitions : 257 | Score :  23
# Episode  380 started --->  Transitions : 140 | Score :  18
# Episode  381 started --->  Transitions : 266 | Score :  26
# Episode  382 started --->  Transitions : 167 | Score :  19
# Episode  383 started --->  Transitions : 435 | Score :  37
# Episode  384 started --->  Transitions : 298 | Score :  29
# Episode  385 started --->  Transitions : 153 | Score :  20
# Episode  386 started --->  Transitions : 223 | Score :  23
# Episode  387 started --->  Transitions : 289 | Score :  26
# Episode  388 started --->  Transitions : 107 | Score :  14
# Episode  389 started --->  Transitions : 142 | Score :  20
# Episode  390 started --->  Transitions : 279 | Score :  29
# Episode  391 started --->  Transitions : 177 | Score :  20
# Episode  392 started --->  Transitions : 136 | Score :  16
# Episode  393 started --->  Transitions : 246 | Score :  25
# Episode  394 started --->  Transitions : 275 | Score :  26
# Episode  395 started --->  Transitions : 313 | Score :  30
# Episode  396 started --->  Transitions : 190 | Score :  18
# Episode  397 started --->  Transitions : 147 | Score :  16
# Episode  398 started --->  Transitions :  47 | Score :   6
# Episode  399 started --->  Transitions : 356 | Score :  34
# Episode  400 started --->  Transitions : 177 | Score :  16
# Episode  401 started --->  Transitions : 138 | Score :  16
# Episode  402 started --->  Transitions : 103 | Score :  12
# Episode  403 started --->  Transitions : 239 | Score :  26
# Episode  404 started --->  Transitions : 252 | Score :  27
# Episode  405 started --->  Transitions : 152 | Score :  15
# Episode  406 started --->  Transitions : 326 | Score :  31
# Episode  407 started --->  Transitions : 170 | Score :  22
# Episode  408 started --->  Transitions : 119 | Score :  17
# Episode  409 started --->  Transitions : 246 | Score :  27
# Episode  410 started --->  Transitions : 115 | Score :  15
# Episode  411 started --->  Transitions : 235 | Score :  26
# Episode  412 started --->  Transitions : 245 | Score :  27
# Episode  413 started --->  Transitions : 281 | Score :  30
# Episode  414 started --->  Transitions :  69 | Score :   8
# Episode  415 started --->  Transitions : 119 | Score :  13
# Episode  416 started --->  Transitions : 125 | Score :  15
# Episode  417 started --->  Transitions : 140 | Score :  15
# Episode  418 started --->  Transitions :  97 | Score :  13
# Episode  419 started --->  Transitions : 122 | Score :  18
# Episode  420 started --->  Transitions : 217 | Score :  21
# Episode  421 started --->  Transitions : 298 | Score :  27
# Episode  422 started --->  Transitions :  66 | Score :   6
# Episode  423 started --->  Transitions : 159 | Score :  21
# Episode  424 started --->  Transitions : 186 | Score :  18
# Episode  425 started --->  Transitions : 211 | Score :  19
# Episode  426 started --->  Transitions : 191 | Score :  21
# Episode  427 started --->  Transitions : 154 | Score :  14
# Episode  428 started --->  Transitions : 301 | Score :  26
# Episode  429 started --->  Transitions : 139 | Score :  21
# Episode  430 started --->  Transitions : 181 | Score :  25
# Episode  431 started --->  Transitions : 269 | Score :  32
# Episode  432 started --->  Transitions : 108 | Score :  13
# Episode  433 started --->  Transitions : 173 | Score :  21
# Episode  434 started --->  Transitions : 189 | Score :  23
# Episode  435 started --->  Transitions : 381 | Score :  34
# Episode  436 started --->  Transitions : 129 | Score :  17
# Episode  437 started --->  Transitions : 174 | Score :  17
# Episode  438 started --->  Transitions : 163 | Score :  16
# Episode  439 started --->  Transitions : 193 | Score :  17
# Episode  440 started --->  Transitions : 280 | Score :  28
# Episode  441 started --->  Transitions : 277 | Score :  23
# Episode  442 started --->  Transitions : 240 | Score :  22
# Episode  443 started --->  Transitions : 116 | Score :  15
# Episode  444 started --->  Transitions : 151 | Score :  19
# Episode  445 started --->  Transitions : 179 | Score :  19
# Episode  446 started --->  Transitions : 184 | Score :  20
# Episode  447 started --->  Transitions : 150 | Score :  15
# Episode  448 started --->  Transitions : 158 | Score :  24
# Episode  449 started --->  Transitions :  97 | Score :  14
# Episode  450 started --->  Transitions : 188 | Score :  21
# Episode  451 started --->  Transitions :  81 | Score :   8
# Episode  452 started --->  Transitions : 231 | Score :  21
# Episode  453 started --->  Transitions : 189 | Score :  22
# Episode  454 started --->  Transitions : 199 | Score :  20
# Episode  455 started --->  Transitions : 225 | Score :  27
# Episode  456 started --->  Transitions : 380 | Score :  29
# Episode  457 started --->  Transitions : 223 | Score :  27
# Episode  458 started --->  Transitions : 285 | Score :  28
# Episode  459 started --->  Transitions : 167 | Score :  18
# Episode  460 started --->  Transitions : 182 | Score :  18
# Episode  461 started --->  Transitions : 179 | Score :  21
# Episode  462 started --->  Transitions : 275 | Score :  31
# Episode  463 started --->  Transitions : 153 | Score :  17
# Episode  464 started --->  Transitions : 121 | Score :  16
# Episode  465 started --->  Transitions : 213 | Score :  18
# Episode  466 started --->  Transitions : 140 | Score :  19
# Episode  467 started --->  Transitions : 130 | Score :  13
# Episode  468 started --->  Transitions : 235 | Score :  25
# Episode  469 started --->  Transitions :  94 | Score :  13
# Episode  470 started --->  Transitions : 206 | Score :  24
# Episode  471 started --->  Transitions : 284 | Score :  28
# Episode  472 started --->  Transitions : 189 | Score :  20
# Episode  473 started --->  Transitions : 212 | Score :  22
# Episode  474 started --->  Transitions : 169 | Score :  19
# Episode  475 started --->  Transitions : 145 | Score :  19
# Episode  476 started --->  Transitions :  98 | Score :  13
# Episode  477 started --->  Transitions : 150 | Score :  18
# Episode  478 started --->  Transitions :  81 | Score :   8
# Episode  479 started --->  Transitions : 204 | Score :  20
# Episode  480 started --->  Transitions : 221 | Score :  21
# Episode  481 started --->  Transitions : 190 | Score :  20
# Episode  482 started --->  Transitions : 248 | Score :  23
# Episode  483 started --->  Transitions : 208 | Score :  20
# Episode  484 started --->  Transitions : 260 | Score :  22
# Episode  485 started --->  Transitions : 183 | Score :  20
# Episode  486 started --->  Transitions : 219 | Score :  21
# Episode  487 started --->  Transitions : 151 | Score :  21
# Episode  488 started --->  Transitions :  60 | Score :   7
# Episode  489 started --->  Transitions : 202 | Score :  19
# Episode  490 started --->  Transitions : 249 | Score :  25
# Episode  491 started --->  Transitions : 197 | Score :  18
# Episode  492 started --->  Transitions : 133 | Score :  16
# Episode  493 started --->  Transitions : 270 | Score :  23
# Episode  494 started --->  Transitions : 117 | Score :  14
# Episode  495 started --->  Transitions : 270 | Score :  23
# Episode  496 started --->  Transitions : 115 | Score :  13
# Episode  497 started --->  Transitions : 105 | Score :  14
# Episode  498 started --->  Transitions : 217 | Score :  22
# Episode  499 started --->  Transitions : 147 | Score :  16
# Episode  500 started --->  Transitions :  81 | Score :   9
# Episode  501 started --->  Transitions : 104 | Score :  12
# Episode  502 started --->  Transitions : 164 | Score :  19
# Episode  503 started --->  Transitions :  52 | Score :   7
# Episode  504 started --->  Transitions : 198 | Score :  20
# Episode  505 started --->  Transitions : 235 | Score :  26
# Episode  506 started --->  Transitions : 247 | Score :  23
# Episode  507 started --->  Transitions : 299 | Score :  23
# Episode  508 started --->  Transitions : 231 | Score :  23
# Episode  509 started --->  Transitions :  90 | Score :  11
# Episode  510 started --->  Transitions : 159 | Score :  19
# Episode  511 started --->  Transitions :  79 | Score :   9
# Episode  512 started --->  Transitions : 168 | Score :  19
# Episode  513 started --->  Transitions : 104 | Score :  12
# Episode  514 started --->  Transitions : 186 | Score :  22
# Episode  515 started --->  Transitions : 160 | Score :  19
# Episode  516 started --->  Transitions : 290 | Score :  27
# Episode  517 started --->  Transitions : 140 | Score :  16
# Episode  518 started --->  Transitions :  58 | Score :   8
# Episode  519 started --->  Transitions : 172 | Score :  19
# Episode  520 started --->  Transitions : 380 | Score :  30
# Episode  521 started --->  Transitions : 268 | Score :  35
# Episode  522 started --->  Transitions :  79 | Score :   8
# Episode  523 started --->  Transitions : 260 | Score :  26
# Episode  524 started --->  Transitions : 276 | Score :  31
# Episode  525 started --->  Transitions :  80 | Score :   9
# Episode  526 started --->  Transitions : 341 | Score :  30
# Episode  527 started --->  Transitions :  62 | Score :   9
# Episode  528 started --->  Transitions : 182 | Score :  21
# Episode  529 started --->  Transitions : 261 | Score :  25
# Episode  530 started --->  Transitions : 287 | Score :  27
# Episode  531 started --->  Transitions :  56 | Score :   7
# Episode  532 started --->  Transitions : 408 | Score :  34
# Episode  533 started --->  Transitions :  69 | Score :  11
# Episode  534 started --->  Transitions : 102 | Score :  13
# Episode  535 started --->  Transitions : 323 | Score :  30
# Episode  536 started --->  Transitions : 310 | Score :  27
# Episode  537 started --->  Transitions : 215 | Score :  21
# Episode  538 started --->  Transitions :  65 | Score :   9
# Episode  539 started --->  Transitions : 169 | Score :  21
# Episode  540 started --->  Transitions : 267 | Score :  26
# Episode  541 started --->  Transitions : 123 | Score :  15
# Episode  542 started --->  Transitions : 348 | Score :  30
# Episode  543 started --->  Transitions :  69 | Score :  10
# Episode  544 started --->  Transitions : 324 | Score :  30
# Episode  545 started --->  Transitions : 135 | Score :  19
# Episode  546 started --->  Transitions : 270 | Score :  24
# Episode  547 started --->  Transitions : 183 | Score :  23
# Episode  548 started --->  Transitions : 272 | Score :  24
# Episode  549 started --->  Transitions : 307 | Score :  28
# Episode  550 started --->  Transitions : 131 | Score :  17
# Episode  551 started --->  Transitions : 172 | Score :  15
# Episode  552 started --->  Transitions : 218 | Score :  22
# Episode  553 started --->  Transitions : 221 | Score :  22
# Episode  554 started --->  Transitions : 167 | Score :  24
# Episode  555 started --->  Transitions :  90 | Score :  10
# Episode  556 started --->  Transitions : 136 | Score :  15
# Episode  557 started --->  Transitions : 131 | Score :  17
# Episode  558 started --->  Transitions : 159 | Score :  22
# Episode  559 started --->  Transitions : 240 | Score :  20
# Episode  560 started --->  Transitions : 207 | Score :  22
# Episode  561 started --->  Transitions : 340 | Score :  32
# Episode  562 started --->  Transitions : 180 | Score :  19
# Episode  563 started --->  Transitions : 183 | Score :  17
# Episode  564 started --->  Transitions :  64 | Score :   7
# Episode  565 started --->  Transitions : 189 | Score :  21
# Episode  566 started --->  Transitions : 241 | Score :  22
# Episode  567 started --->  Transitions : 168 | Score :  20
# Episode  568 started --->  Transitions : 355 | Score :  28
# Episode  569 started --->  Transitions : 182 | Score :  19
# Episode  570 started --->  Transitions : 208 | Score :  25
# Episode  571 started --->  Transitions :  76 | Score :   9
# Episode  572 started --->  Transitions : 268 | Score :  25
# Episode  573 started --->  Transitions : 147 | Score :  19
# Episode  574 started --->  Transitions :  43 | Score :   6
# Episode  575 started --->  Transitions : 135 | Score :  15
# Episode  576 started --->  Transitions : 112 | Score :  13
# Episode  577 started --->  Transitions : 273 | Score :  27
# Episode  578 started --->  Transitions : 257 | Score :  24
# Episode  579 started --->  Transitions : 209 | Score :  20
# Episode  580 started --->  Transitions : 216 | Score :  26
# Episode  581 started --->  Transitions : 137 | Score :  16
# Episode  582 started --->  Transitions : 200 | Score :  19
# Episode  583 started --->  Transitions : 257 | Score :  26
# Episode  584 started --->  Transitions : 150 | Score :  18
# Episode  585 started --->  Transitions : 166 | Score :  18
# Episode  586 started --->  Transitions : 206 | Score :  23
# Episode  587 started --->  Transitions : 276 | Score :  27
# Episode  588 started --->  Transitions : 145 | Score :  17
# Episode  589 started --->  Transitions : 271 | Score :  22
# Episode  590 started --->  Transitions : 118 | Score :  12
# Episode  591 started --->  Transitions : 144 | Score :  18
# Episode  592 started --->  Transitions : 186 | Score :  19
# Episode  593 started --->  Transitions : 107 | Score :  12
# Episode  594 started --->  Transitions : 228 | Score :  25
# Episode  595 started --->  Transitions :  89 | Score :  12
# Episode  596 started --->  Transitions : 282 | Score :  27
# Episode  597 started --->  Transitions : 202 | Score :  18
# Episode  598 started --->  Transitions : 180 | Score :  18
# Episode  599 started --->  Transitions : 153 | Score :  16
# Episode  600 started --->  Transitions : 134 | Score :  14
# Episode  601 started --->  Transitions : 240 | Score :  28
# Episode  602 started --->  Transitions : 222 | Score :  23
# Episode  603 started --->  Transitions : 101 | Score :  13
# Episode  604 started --->  Transitions : 268 | Score :  25
# Episode  605 started --->  Transitions : 128 | Score :  14
# Episode  606 started --->  Transitions : 198 | Score :  22
# Episode  607 started --->  Transitions : 104 | Score :  12
# Episode  608 started --->  Transitions : 215 | Score :  21
# Episode  609 started --->  Transitions : 160 | Score :  14
# Episode  610 started --->  Transitions : 101 | Score :  15
# Episode  611 started --->  Transitions : 131 | Score :  15
# Episode  612 started --->  Transitions : 349 | Score :  31
# Episode  613 started --->  Transitions : 186 | Score :  21
# Episode  614 started --->  Transitions : 193 | Score :  24
# Episode  615 started --->  Transitions : 167 | Score :  18
# Episode  616 started --->  Transitions : 254 | Score :  26
# Episode  617 started --->  Transitions : 120 | Score :  16
# Episode  618 started --->  Transitions : 150 | Score :  20
# Episode  619 started --->  Transitions : 283 | Score :  26
# Episode  620 started --->  Transitions : 199 | Score :  20
# Episode  621 started --->  Transitions : 189 | Score :  22
# Episode  622 started --->  Transitions : 287 | Score :  24
# Episode  623 started --->  Transitions : 140 | Score :  16
# Episode  624 started --->  Transitions : 309 | Score :  28
# Episode  625 started --->  Transitions : 127 | Score :  14
# Episode  626 started --->  Transitions : 109 | Score :  12
# Episode  627 started --->  Transitions : 275 | Score :  25
# Episode  628 started --->  Transitions : 129 | Score :  16
# Episode  629 started --->  Transitions : 187 | Score :  19
# Episode  630 started --->  Transitions : 163 | Score :  17
# Episode  631 started --->  Transitions : 304 | Score :  31
# Episode  632 started --->  Transitions :  98 | Score :  11
# Episode  633 started --->  Transitions : 171 | Score :  17
# Episode  634 started --->  Transitions : 148 | Score :  16
# Episode  635 started --->  Transitions : 243 | Score :  22
# Episode  636 started --->  Transitions : 204 | Score :  21
# Episode  637 started --->  Transitions : 209 | Score :  20
# Episode  638 started --->  Transitions : 264 | Score :  26
# Episode  639 started --->  Transitions : 323 | Score :  29
# Episode  640 started --->  Transitions : 227 | Score :  26
# Episode  641 started --->  Transitions : 166 | Score :  17
# Episode  642 started --->  Transitions : 175 | Score :  19
# Episode  643 started --->  Transitions : 130 | Score :  16
# Episode  644 started --->  Transitions : 198 | Score :  23
# Episode  645 started --->  Transitions : 143 | Score :  14
# Episode  646 started --->  Transitions : 208 | Score :  23
# Episode  647 started --->  Transitions : 381 | Score :  34
# Episode  648 started --->  Transitions : 204 | Score :  19
# Episode  649 started --->  Transitions : 189 | Score :  18
# Episode  650 started --->  Transitions : 211 | Score :  21
# Episode  651 started --->  Transitions : 188 | Score :  19
# Episode  652 started --->  Transitions :  84 | Score :   9
# Episode  653 started --->  Transitions : 165 | Score :  19
# Episode  654 started --->  Transitions : 317 | Score :  30
# Episode  655 started --->  Transitions : 153 | Score :  17
# Episode  656 started --->  Transitions : 149 | Score :  17
# Episode  657 started --->  Transitions : 390 | Score :  38
# Episode  658 started --->  Transitions : 129 | Score :  14
# Episode  659 started --->  Transitions : 281 | Score :  29
# Episode  660 started --->  Transitions : 178 | Score :  23
# Episode  661 started --->  Transitions :  79 | Score :   8
# Episode  662 started --->  Transitions :  82 | Score :  11
# Episode  663 started --->  Transitions : 134 | Score :  15
# Episode  664 started --->  Transitions : 145 | Score :  18
# Episode  665 started --->  Transitions : 357 | Score :  29
# Episode  666 started --->  Transitions : 184 | Score :  20
# Episode  667 started --->  Transitions : 232 | Score :  25
# Episode  668 started --->  Transitions : 192 | Score :  16
# Episode  669 started --->  Transitions : 201 | Score :  20
# Episode  670 started --->  Transitions : 261 | Score :  28
# Episode  671 started --->  Transitions : 162 | Score :  20
# Episode  672 started --->  Transitions : 359 | Score :  36
# Episode  673 started --->  Transitions : 215 | Score :  19
# Episode  674 started --->  Transitions : 102 | Score :  12
# Episode  675 started --->  Transitions : 196 | Score :  19
# Episode  676 started --->  Transitions : 219 | Score :  26
# Episode  677 started --->  Transitions :  91 | Score :  11
# Episode  678 started --->  Transitions :  95 | Score :  11
# Episode  679 started --->  Transitions : 165 | Score :  20
# Episode  680 started --->  Transitions : 225 | Score :  23
# Episode  681 started --->  Transitions : 261 | Score :  26
# Episode  682 started --->  Transitions : 289 | Score :  30
# Episode  683 started --->  Transitions : 238 | Score :  27
# Episode  684 started --->  Transitions : 198 | Score :  21
# Episode  685 started --->  Transitions : 143 | Score :  15
# Episode  686 started --->  Transitions :  66 | Score :   9
# Episode  687 started --->  Transitions : 324 | Score :  33
# Episode  688 started --->  Transitions : 277 | Score :  25
# Episode  689 started --->  Transitions : 198 | Score :  21
# Episode  690 started --->  Transitions : 224 | Score :  22
# Episode  691 started --->  Transitions :  92 | Score :  10
# Episode  692 started --->  Transitions : 183 | Score :  16
# Episode  693 started --->  Transitions : 202 | Score :  22
# Episode  694 started --->  Transitions :  71 | Score :   9
# Episode  695 started --->  Transitions : 176 | Score :  18
# Episode  696 started --->  Transitions : 125 | Score :  15
# Episode  697 started --->  Transitions : 148 | Score :  18
# Episode  698 started --->  Transitions : 274 | Score :  29
# Episode  699 started --->  Transitions : 140 | Score :  19
# Episode  700 started --->  Transitions : 131 | Score :  17
# Episode  701 started --->  Transitions : 188 | Score :  23
# Episode  702 started --->  Transitions : 184 | Score :  22
# Episode  703 started --->  Transitions :  74 | Score :   8
# Episode  704 started --->  Transitions : 176 | Score :  24
# Episode  705 started --->  Transitions : 184 | Score :  17
# Episode  706 started --->  Transitions :  28 | Score :   7
# Episode  707 started --->  Transitions : 330 | Score :  31
# Episode  708 started --->  Transitions : 135 | Score :  17
# Episode  709 started --->  Transitions : 232 | Score :  26
# Episode  710 started --->  Transitions : 304 | Score :  31
# Episode  711 started --->  Transitions : 189 | Score :  22
# Episode  712 started --->  Transitions : 161 | Score :  17
# Episode  713 started --->  Transitions :  68 | Score :   8
# Episode  714 started --->  Transitions : 182 | Score :  23
# Episode  715 started --->  Transitions : 125 | Score :  19
# Episode  716 started --->  Transitions : 209 | Score :  23
# Episode  717 started --->  Transitions : 182 | Score :  20
# Episode  718 started --->  Transitions : 276 | Score :  28
# Episode  719 started --->  Transitions : 177 | Score :  15
# Episode  720 started --->  Transitions : 227 | Score :  23
# Episode  721 started --->  Transitions : 237 | Score :  19
# Episode  722 started --->  Transitions : 274 | Score :  25
# Episode  723 started --->  Transitions : 359 | Score :  36
# Episode  724 started --->  Transitions : 166 | Score :  18
# Episode  725 started --->  Transitions : 163 | Score :  16
# Episode  726 started --->  Transitions : 112 | Score :   9
# Episode  727 started --->  Transitions :  60 | Score :   7
# Episode  728 started --->  Transitions : 196 | Score :  23
# Episode  729 started --->  Transitions : 334 | Score :  34
# Episode  730 started --->  Transitions :  99 | Score :  14
# Episode  731 started --->  Transitions : 256 | Score :  34
# Episode  732 started --->  Transitions : 162 | Score :  19
# Episode  733 started --->  Transitions : 192 | Score :  21
# Episode  734 started --->  Transitions : 197 | Score :  19
# Episode  735 started --->  Transitions : 269 | Score :  24
# Episode  736 started --->  Transitions : 126 | Score :  19
# Episode  737 started --->  Transitions : 153 | Score :  20
# Episode  738 started --->  Transitions : 189 | Score :  22
# Episode  739 started --->  Transitions : 110 | Score :  14
# Episode  740 started --->  Transitions : 349 | Score :  30
# Episode  741 started --->  Transitions : 299 | Score :  26
# Episode  742 started --->  Transitions : 108 | Score :  14
# Episode  743 started --->  Transitions : 178 | Score :  18
# Episode  744 started --->  Transitions : 297 | Score :  27
# Episode  745 started --->  Transitions : 163 | Score :  16
# Episode  746 started --->  Transitions : 239 | Score :  24
# Episode  747 started --->  Transitions : 257 | Score :  30
# Episode  748 started --->  Transitions : 197 | Score :  19
# Episode  749 started --->  Transitions : 186 | Score :  21
# Episode  750 started --->  Transitions : 192 | Score :  22
# Episode  751 started --->  Transitions : 365 | Score :  31
# Episode  752 started --->  Transitions : 129 | Score :  16
# Episode  753 started --->  Transitions : 178 | Score :  18
# Episode  754 started --->  Transitions :  79 | Score :  10
# Episode  755 started --->  Transitions :  88 | Score :  10
# Episode  756 started --->  Transitions : 298 | Score :  26
# Episode  757 started --->  Transitions : 233 | Score :  24
# Episode  758 started --->  Transitions : 190 | Score :  20
# Episode  759 started --->  Transitions : 225 | Score :  24
# Episode  760 started --->  Transitions :  95 | Score :  11
# Episode  761 started --->  Transitions : 127 | Score :  17
# Episode  762 started --->  Transitions :  93 | Score :  12
# Episode  763 started --->  Transitions : 153 | Score :  20
# Episode  764 started --->  Transitions : 184 | Score :  17
# Episode  765 started --->  Transitions : 139 | Score :  15
# Episode  766 started --->  Transitions : 139 | Score :  17
# Episode  767 started --->  Transitions : 212 | Score :  20
# Episode  768 started --->  Transitions : 292 | Score :  29
# Episode  769 started --->  Transitions : 118 | Score :  17
# Episode  770 started --->  Transitions : 140 | Score :  16
# Episode  771 started --->  Transitions : 228 | Score :  23
# Episode  772 started --->  Transitions : 226 | Score :  24
# Episode  773 started --->  Transitions : 170 | Score :  20
# Episode  774 started --->  Transitions : 188 | Score :  20
# Episode  775 started --->  Transitions :  89 | Score :   9
# Episode  776 started --->  Transitions : 156 | Score :  20
# Episode  777 started --->  Transitions :  74 | Score :  10
# Episode  778 started --->  Transitions : 224 | Score :  23
# Episode  779 started --->  Transitions : 206 | Score :  23
# Episode  780 started --->  Transitions : 224 | Score :  25
# Episode  781 started --->  Transitions : 170 | Score :  18
# Episode  782 started --->  Transitions : 250 | Score :  25
# Episode  783 started --->  Transitions : 202 | Score :  21
# Episode  784 started --->  Transitions : 169 | Score :  16
# Episode  785 started --->  Transitions : 251 | Score :  25
# Episode  786 started --->  Transitions : 225 | Score :  24
# Episode  787 started --->  Transitions : 211 | Score :  22
# Episode  788 started --->  Transitions : 112 | Score :  14
# Episode  789 started --->  Transitions : 253 | Score :  25
# Episode  790 started --->  Transitions : 352 | Score :  30
# Episode  791 started --->  Transitions : 248 | Score :  28
# Episode  792 started --->  Transitions : 186 | Score :  21
# Episode  793 started --->  Transitions : 170 | Score :  18
# Episode  794 started --->  Transitions : 228 | Score :  25
# Episode  795 started --->  Transitions : 258 | Score :  24
# Episode  796 started --->  Transitions : 235 | Score :  23
# Episode  797 started --->  Transitions : 241 | Score :  25
# Episode  798 started --->  Transitions :  85 | Score :  10
# Episode  799 started --->  Transitions : 290 | Score :  26
# Episode  800 started --->  Transitions :  79 | Score :   9
# Episode  801 started --->  Transitions : 202 | Score :  22
# Episode  802 started --->  Transitions : 148 | Score :  15
# Episode  803 started --->  Transitions : 148 | Score :  19
# Episode  804 started --->  Transitions : 230 | Score :  24
# Episode  805 started --->  Transitions :  90 | Score :  10
# Episode  806 started --->  Transitions : 212 | Score :  22
# Episode  807 started --->  Transitions : 243 | Score :  27
# Episode  808 started --->  Transitions : 222 | Score :  21
# Episode  809 started --->  Transitions : 169 | Score :  19
# Episode  810 started --->  Transitions : 246 | Score :  27
# Episode  811 started --->  Transitions : 221 | Score :  21
# Episode  812 started --->  Transitions : 164 | Score :  17
# Episode  813 started --->  Transitions : 249 | Score :  28
# Episode  814 started --->  Transitions : 211 | Score :  22
# Episode  815 started --->  Transitions : 138 | Score :  17
# Episode  816 started --->  Transitions : 312 | Score :  29
# Episode  817 started --->  Transitions : 215 | Score :  20
# Episode  818 started --->  Transitions : 141 | Score :  14
# Episode  819 started --->  Transitions : 215 | Score :  20
# Episode  820 started --->  Transitions : 225 | Score :  24
# Episode  821 started --->  Transitions : 317 | Score :  29
# Episode  822 started --->  Transitions : 198 | Score :  21
# Episode  823 started --->  Transitions : 209 | Score :  22
# Episode  824 started --->  Transitions : 173 | Score :  17
# Episode  825 started --->  Transitions : 131 | Score :  15
# Episode  826 started --->  Transitions : 197 | Score :  20
# Episode  827 started --->  Transitions : 152 | Score :  18
# Episode  828 started --->  Transitions : 104 | Score :  11
# Episode  829 started --->  Transitions : 137 | Score :  16
# Episode  830 started --->  Transitions : 261 | Score :  27
# Episode  831 started --->  Transitions : 117 | Score :  11
# Episode  832 started --->  Transitions : 170 | Score :  21
# Episode  833 started --->  Transitions : 195 | Score :  18
# Episode  834 started --->  Transitions : 263 | Score :  27
# Episode  835 started --->  Transitions : 161 | Score :  17
# Episode  836 started --->  Transitions : 223 | Score :  23
# Episode  837 started --->  Transitions : 186 | Score :  20
# Episode  838 started --->  Transitions : 143 | Score :  18
# Episode  839 started --->  Transitions : 228 | Score :  21
# Episode  840 started --->  Transitions : 116 | Score :  13
# Episode  841 started --->  Transitions : 145 | Score :  18
# Episode  842 started --->  Transitions : 176 | Score :  18
# Episode  843 started --->  Transitions : 180 | Score :  24
# Episode  844 started --->  Transitions : 184 | Score :  21
# Episode  845 started --->  Transitions : 139 | Score :  14
# Episode  846 started --->  Transitions : 125 | Score :  15
# Episode  847 started --->  Transitions : 287 | Score :  28
# Episode  848 started --->  Transitions :  73 | Score :  10
# Episode  849 started --->  Transitions : 133 | Score :  14
# Episode  850 started --->  Transitions :  71 | Score :   6
# Episode  851 started --->  Transitions : 260 | Score :  24
# Episode  852 started --->  Transitions : 272 | Score :  27
# Episode  853 started --->  Transitions : 256 | Score :  25
# Episode  854 started --->  Transitions : 230 | Score :  24
# Episode  855 started --->  Transitions : 125 | Score :  14
# Episode  856 started --->  Transitions : 191 | Score :  22
# Episode  857 started --->  Transitions : 151 | Score :  15
# Episode  858 started --->  Transitions : 218 | Score :  21
# Episode  859 started --->  Transitions : 166 | Score :  18
# Episode  860 started --->  Transitions : 197 | Score :  17
# Episode  861 started --->  Transitions : 210 | Score :  19
# Episode  862 started --->  Transitions : 169 | Score :  20
# Episode  863 started --->  Transitions : 110 | Score :  12
# Episode  864 started --->  Transitions :  66 | Score :  10
# Episode  865 started --->  Transitions : 202 | Score :  20
# Episode  866 started --->  Transitions : 246 | Score :  24
# Episode  867 started --->  Transitions : 204 | Score :  23
# Episode  868 started --->  Transitions : 221 | Score :  26
# Episode  869 started --->  Transitions :  97 | Score :  12
# Episode  870 started --->  Transitions : 296 | Score :  28
# Episode  871 started --->  Transitions : 242 | Score :  22
# Episode  872 started --->  Transitions : 123 | Score :  14
# Episode  873 started --->  Transitions : 248 | Score :  25
# Episode  874 started --->  Transitions : 150 | Score :  16
# Episode  875 started --->  Transitions : 221 | Score :  24
# Episode  876 started --->  Transitions : 307 | Score :  28
# Episode  877 started --->  Transitions : 166 | Score :  20
# Episode  878 started --->  Transitions : 120 | Score :  12
# Episode  879 started --->  Transitions : 214 | Score :  21
# Episode  880 started --->  Transitions : 252 | Score :  28
# Episode  881 started --->  Transitions : 168 | Score :  18
# Episode  882 started --->  Transitions : 215 | Score :  21
# Episode  883 started --->  Transitions : 149 | Score :  16
# Episode  884 started --->  Transitions : 160 | Score :  16
# Episode  885 started --->  Transitions : 130 | Score :  14
# Episode  886 started --->  Transitions : 147 | Score :  17
# Episode  887 started --->  Transitions : 154 | Score :  18
# Episode  888 started --->  Transitions : 294 | Score :  30
# Episode  889 started --->  Transitions : 200 | Score :  20
# Episode  890 started --->  Transitions : 201 | Score :  18
# Episode  891 started --->  Transitions : 284 | Score :  26
# Episode  892 started --->  Transitions : 300 | Score :  29
# Episode  893 started --->  Transitions : 366 | Score :  35
# Episode  894 started --->  Transitions : 426 | Score :  35
# Episode  895 started --->  Transitions : 245 | Score :  25
# Episode  896 started --->  Transitions : 283 | Score :  23
# Episode  897 started --->  Transitions : 108 | Score :  13
# Episode  898 started --->  Transitions : 170 | Score :  17
# Episode  899 started --->  Transitions : 119 | Score :  13
# Episode  900 started --->  Transitions :  97 | Score :   9
# Episode  901 started --->  Transitions : 161 | Score :  25
# Episode  902 started --->  Transitions : 233 | Score :  27
# Episode  903 started --->  Transitions : 156 | Score :  18
# Episode  904 started --->  Transitions : 160 | Score :  17
# Episode  905 started --->  Transitions :  49 | Score :   5
# Episode  906 started --->  Transitions : 279 | Score :  32
# Episode  907 started --->  Transitions : 190 | Score :  24
# Episode  908 started --->  Transitions : 240 | Score :  23
# Episode  909 started --->  Transitions : 292 | Score :  30
# Episode  910 started --->  Transitions : 189 | Score :  20
# Episode  911 started --->  Transitions : 177 | Score :  20
# Episode  912 started --->  Transitions : 284 | Score :  26
# Episode  913 started --->  Transitions :  68 | Score :  10
# Episode  914 started --->  Transitions : 337 | Score :  32
# Episode  915 started --->  Transitions : 181 | Score :  19
# Episode  916 started --->  Transitions : 359 | Score :  33
# Episode  917 started --->  Transitions : 144 | Score :  14
# Episode  918 started --->  Transitions : 294 | Score :  29
# Episode  919 started --->  Transitions : 296 | Score :  27
# Episode  920 started --->  Transitions :  95 | Score :  11
# Episode  921 started --->  Transitions : 233 | Score :  20
# Episode  922 started --->  Transitions : 207 | Score :  21
# Episode  923 started --->  Transitions : 198 | Score :  20
# Episode  924 started --->  Transitions : 234 | Score :  22
# Episode  925 started --->  Transitions : 251 | Score :  26
# Episode  926 started --->  Transitions : 210 | Score :  23
# Episode  927 started --->  Transitions : 244 | Score :  20
# Episode  928 started --->  Transitions : 281 | Score :  30
# Episode  929 started --->  Transitions : 217 | Score :  24
# Episode  930 started --->  Transitions : 378 | Score :  32
# Episode  931 started --->  Transitions : 316 | Score :  26
# Episode  932 started --->  Transitions : 334 | Score :  38
# Episode  933 started --->  Transitions : 165 | Score :  23
# Episode  934 started --->  Transitions : 179 | Score :  20
# Episode  935 started --->  Transitions :  64 | Score :   8
# Episode  936 started --->  Transitions : 221 | Score :  26
# Episode  937 started --->  Transitions : 138 | Score :  17
# Episode  938 started --->  Transitions : 123 | Score :  16
# Episode  939 started --->  Transitions : 124 | Score :  15
# Episode  940 started --->  Transitions : 129 | Score :  15
# Episode  941 started --->  Transitions : 297 | Score :  31
# Episode  942 started --->  Transitions : 239 | Score :  26
# Episode  943 started --->  Transitions : 276 | Score :  25
# Episode  944 started --->  Transitions : 158 | Score :  15
# Episode  945 started --->  Transitions : 178 | Score :  19
# Episode  946 started --->  Transitions : 219 | Score :  23
# Episode  947 started --->  Transitions : 230 | Score :  23
# Episode  948 started --->  Transitions : 152 | Score :  14
# Episode  949 started --->  Transitions : 169 | Score :  16
# Episode  950 started --->  Transitions : 198 | Score :  22
# Episode  951 started --->  Transitions : 255 | Score :  26
# Episode  952 started --->  Transitions : 203 | Score :  18
# Episode  953 started --->  Transitions : 322 | Score :  31
# Episode  954 started --->  Transitions : 260 | Score :  24
# Episode  955 started --->  Transitions : 310 | Score :  27
# Episode  956 started --->  Transitions : 200 | Score :  24
# Episode  957 started --->  Transitions : 267 | Score :  26
# Episode  958 started --->  Transitions : 307 | Score :  27
# Episode  959 started --->  Transitions : 215 | Score :  27
# Episode  960 started --->  Transitions : 181 | Score :  20
# Episode  961 started --->  Transitions : 217 | Score :  20
# Episode  962 started --->  Transitions : 248 | Score :  26
# Episode  963 started --->  Transitions : 181 | Score :  19
# Episode  964 started --->  Transitions :   6 | Score :   1
# Episode  965 started --->  Transitions : 145 | Score :  18
# Episode  966 started --->  Transitions : 271 | Score :  24
# Episode  967 started --->  Transitions : 343 | Score :  31
# Episode  968 started --->  Transitions : 172 | Score :  18
# Episode  969 started --->  Transitions :  85 | Score :  10
# Episode  970 started --->  Transitions :  83 | Score :   9
# Episode  971 started --->  Transitions : 243 | Score :  24
# Episode  972 started --->  Transitions : 253 | Score :  26
# Episode  973 started --->  Transitions : 156 | Score :  17
# Episode  974 started --->  Transitions : 193 | Score :  20
# Episode  975 started --->  Transitions : 158 | Score :  18
# Episode  976 started --->  Transitions : 126 | Score :  13
# Episode  977 started --->  Transitions : 241 | Score :  22
# Episode  978 started --->  Transitions : 262 | Score :  29
# Episode  979 started --->  Transitions : 178 | Score :  17
# Episode  980 started --->  Transitions : 181 | Score :  21
# Episode  981 started --->  Transitions : 202 | Score :  21
# Episode  982 started --->  Transitions : 267 | Score :  27
# Episode  983 started --->  Transitions : 206 | Score :  22
# Episode  984 started --->  Transitions : 152 | Score :  18
# Episode  985 started --->  Transitions : 213 | Score :  22
# Episode  986 started --->  Transitions : 302 | Score :  29
# Episode  987 started --->  Transitions : 323 | Score :  25
# Episode  988 started --->  Transitions : 185 | Score :  18
# Episode  989 started --->  Transitions : 319 | Score :  28
# Episode  990 started --->  Transitions : 158 | Score :  15
# Episode  991 started --->  Transitions : 231 | Score :  27
# Episode  992 started --->  Transitions : 291 | Score :  29
# Episode  993 started --->  Transitions : 189 | Score :  18
# Episode  994 started --->  Transitions : 162 | Score :  18
# Episode  995 started --->  Transitions : 194 | Score :  20
# Episode  996 started --->  Transitions : 107 | Score :  13
# Episode  997 started --->  Transitions : 208 | Score :  23
# Episode  998 started --->  Transitions : 171 | Score :  17
# Episode  999 started --->  Transitions : 192 | Score :  19
# Episode 1000 started --->  Transitions : 150 | Score :  21
# ____________________________________________________
# Results of 1000 episode:
# Mean(socres) = 20.257
# std(socres) = 6.502534198295308
# Max(socres) = 41

# %%
# Test (showing the frames)

from functions import return_state_frame
scores = [] 

for episode in range(1,1+1):

    loose = False
    step = 0
    snake= Agent(dimension)
    food,_ = food_init(dimension,snake.path)    
    current_state,frame = return_state_frame(snake.path , food)  #  np array ([4, features])  
    score = 0 
    plt.imshow(frame, cmap="gray")
    plt.show()

    while loose != True: # Not loose
        time.sleep(0.3)
        clear_output(wait=True)
        # os.system('cls') 

        tensor_current_state = torch.from_numpy(current_state)
        if cuda.is_available():
          tensor_current_state = tensor_current_state.cuda()
        
        Q_policy.eval()
        with torch.no_grad():
          out = Q_policy(tensor_current_state)

        best_action = int(torch.argmax( out ))
        action = best_action # action is 0, 1, 2 or 3 

        snake.move(action_to_direction[action],dimension)
        step += 1

        if snake.head[0] == food.x and snake.head[1] == food.y:  # Eating food
            score += 1
            food, isFinished = food_init(dimension,snake.path) # Initializing the food position
            loose = isFinished
            new_state,frame = return_state_frame(snake.path,food)  #  np array ([1, features])  

   
        elif snake.head in snake.path[1:-1]: # Loose : runs into itself
            loose = True
            snake.path.pop(0) # Removing the tail
            new_state,frame = return_state_frame(snake.path , food)  #  np array ([1, features])  
            scores.append(score)
           
            
        elif (snake.head[0] in [0,dimension-1]) or (snake.head[1] in [0,dimension-1]): # Loose : runs into the wall
            loose = True
            snake.path.pop(0) # Removing the tail
            new_state,frame = return_state_frame(snake.path , food)  #  np array ([1, features])  
            scores.append(score)
        
        else : # Just moved
            snake.path.pop(0) # Removing the tail
            new_state,frame = return_state_frame(snake.path , food)  #  np array ([1, features])  

        current_state = new_state.copy()
        plt.imshow(frame, cmap="gray")
        plt.show()

        if (loose == True) :
              print("Transitions : {0:3d}".format(step),end=" | ")
              print("Score : {0:3d}".format(score))
# Out:
# Transitions : 271 | Score :  25
